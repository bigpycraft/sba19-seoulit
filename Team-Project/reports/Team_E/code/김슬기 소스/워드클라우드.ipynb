# %%
import pytagcloud
import pandas as pd
import pytagcloud as tagcloud
from IPython.display import Image 
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#트위터 15,16,19
df1=pd.read_excel("keys_values_15.xlsx")
df2=pd.read_excel("keys_values_16-19_06.xlsx")
df3=pd.read_excel("keys_values_19_07.xlsx")

#트위터 비교 
df4=pd.read_excel("common_15_and_19.xlsx")
df5=pd.read_excel("common_nouns(1).xlsx")

#뉴스
df6=pd.read_excel("chosun_final.xlsx")
df7=pd.read_excel("donga_final.xlsx")
df8=pd.read_excel("hankyung.xlsx")
df9=pd.read_excel("hankyure_final.xlsx")
df10=pd.read_excel("maekyung_final.xlsx")
df11=pd.read_excel("kyunghyang_final.xlsx")

#뉴스 비교
df12=pd.read_excel("Jinbo_common_nouns.xlsx")
df13=pd.read_excel("bosu_common_nouns.xlsx")
df14=pd.read_excel("economy_common_nouns.xlsx")

df15=pd.read_excel("news_common_nouns.xlsx")
#트위터 뉴스비교
df16=pd.read_excel("twitter_and_news_common_nouns.xlsx")

# %%
df5["sum"]=''
for i in range(0,len(df5)):
    df5["sum"][i]=df5["2015"][i]+df5["2016~2019 before July"][i]+df5["2019 after July"][i]
# Out:
# C:\Python\py\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#news_2015=pd.read_excel('2019_word_list_final.xlsx')

# %%
#df1.drop('Unnamed: 0',axis=1,inplace=True)
#df2.drop('Unnamed: 0',axis=1,inplace=True)
#df3.drop('Unnamed: 0',axis=1,inplace=True)
#df4.drop('Unnamed: 0',axis=1,inplace=True)
#df5.drop('Unnamed: 0',axis=1,inplace=True)
#df6.drop('Unnamed: 0',axis=1,inplace=True)
#df7.drop('Unnamed: 0',axis=1,inplace=True)
#df8.drop('Unnamed: 0',axis=1,inplace=True)
#df9.drop('Unnamed: 0',axis=1,inplace=True)
#df10.drop('Unnamed: 0',axis=1,inplace=True)
#df11.drop('Unnamed: 0',axis=1,inplace=True)
#df12.drop('Unnamed: 0',axis=1,inplace=True)
#df13.drop('Unnamed: 0',axis=1,inplace=True)
#df14.drop('Unnamed: 0',axis=1,inplace=True)
df15.drop('Unnamed: 0',axis=1,inplace=True)
df16.drop('Unnamed: 0',axis=1,inplace=True)

# %%
#df=df.sort_values(["values"],ascending=[False])
df10=df10.sort_values(["size"],ascending=[False])
df8=df8.sort_values(["size"],ascending=[False])
df5=df5.sort_values(["sum"],ascending=[False])

# %%
df1=df1.sort_values(["values"],ascending=[False])
df2=df2.sort_values(["values"],ascending=[False])
df3=df3.sort_values(["values"],ascending=[False])
df4=df4.sort_values(["values"],ascending=[False])

df6=df6.sort_values(["values"],ascending=[False])
df7=df7.sort_values(["values"],ascending=[False])

df9=df9.sort_values(["values"],ascending=[False])

# %%
df10
# Out:
#                 tag  size
# 0                한국   631
# 1                정부   436
# 2                제품   424
# 3                국내   331
# 4                기업   293
# 5                맥주   254
# 6               브랜드   234
# 7                매출   218
# 8                경제   206
# 9                수출   200
# 10               조치   196
# 11               감소   169
# 12             유니클로   166
# 13               문제   165
# 14               대비   165
# 15               판매   151
# 16               여행   143
# 17               규제   132
# 18               한일   131
# 19               아베   130
# 20               회장   125
# 21               상황   124
# 22               보복   117
# 23               매장   112
# 24               시장   112
# 25              대통령   111
# 26               대응   107
# 27               미국   105
# 28               노선    96
# 29               국민    95
# ...             ...   ...
# 3612        관건"GS25     1
# 3611        유통·패션업계     1
# 3610             유지     1
# ...

# %%
df1=df1.head(100)
df2=df2.head(100)
df3=df3.head(100)
df4=df4.head(100)
df5=df5.head(100)#sum
df6=df6.head(100)
df7=df7.head(100)
df8=df8.head(100)#size
df9=df9.head(100)
df10=df10.head(100)#size
df11=df11.head(100)
df12=df12.head(100)
df13=df13.head(100)
df14=df14.head(100)
df15=df15.head(100)
df16=df16.head(100)

# %%
df5.values
# Out:
# array([[17, '매출', 200, 40, 170, 410],
#        [16, '출시', 180, 40, 170, 390],
#        [2, '조국', 62, 72, 180, 314],
#        [7, '올림픽', 51, 55, 180, 286],
#        [18, '배제', 78, 38, 170, 286],
#        [0, '다케시마', 3, 88, 180, 271],
#        [3, '반역', 14, 66, 180, 260],
#        [1, '공식', 1, 72, 180, 253],
#        [4, '규제', 1, 66, 180, 247],
#        [6, '일제', 9, 56, 180, 245],
#        [37, '땅', 79, 25, 136, 240],
#        [9, '연합', 14, 55, 170, 239],
#        [5, '소비', 1, 58, 180, 239],
#        [14, '피해', 14, 50, 170, 234],
#        [10, '대적', 1, 55, 170, 226],
#        [12, '미쓰비시', 1, 52, 170, 223],
#        [11, '소송', 1, 52, 170, 223],
#        [13, '전자', 1, 50, 170, 221],
#        [15, '쪽바리', 1, 46, 170, 217],
#        [20, '구조', 9, 37, 170, 216],
#        [21, '가세', 19, 37, 160, 216],
#        [22, '국수', 15, 35, 160, 210],
#        [23, '인식', 15, 35, 160, 210],
#        [24, '특혜', 11, 35, 160, 206],
#        [25, '카드', 6, 35, 160, 201],
# ...

# %% [markdown]
# ## 트위터

# %%
d = {}
for c,a, x in df1.values:
    d[a] = x

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf')
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 16))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
d = {}
for  a, x in df2.values:
    d[a] = x

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf')
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 16))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
d = {}
for a, x in df3.values:
    d[a] = x

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf')
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 16))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 트위터 비교

# %%
import numpy as np
from PIL import Image

# %%
twitter = np.array(Image.open('./images/twit.png'))

# %%
d = {}
for c,a, x in df4.values:
    d[a] = x

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf',mask=twitter, background_color='white',max_font_size=100)
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
d = {}
for c, a,z,r,e, x in df5.values:
    d[a] = x

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf',mask=twitter, background_color='white',max_font_size=100)
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 뉴스비교

# %%
d = {}
for a, x in df12.values:
    d[a] = x

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf',mask=news, background_color="red",max_font_size=80)
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
d = {}
for a, x in df13.values:
    d[a] = x

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf',mask=news, background_color='red',max_font_size=80)
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
d = {}
for a, x in df14.values:
    d[a] = x

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf',mask=news, background_color='red',max_font_size=80)
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
d = {}
for a, x in df15.values:
    d[a] = x

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf',mask=news, background_color='red',max_font_size=80)
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 트위터와 뉴스 비교

# %%
import numpy as np
from PIL import Image

# %%
no_japan = np.array(Image.open('./images/japan.jpg'))

# %%
d = {}
for a, x in df16.values:
    d[a] = x

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf',mask=no_japan, background_color='black',max_font_size=140,colormap="cool")
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
