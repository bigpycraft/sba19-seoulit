# %%
import pandas as pd
# from IPython.display import Image 
# from lxml import html
from collections import Counter
# from urllib.request import urlopen
from konlpy.tag import Hannanum
from tqdm import tqdm_notebook

# import sys
import random
# import webbrowser
import pytagcloud
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
total_news = pd.read_excel('2019_news_final.xlsx')

# %%
# total_news_1 = total_news[].reset_index()
total_news_1 = total_news[0:1000].reset_index()
total_news_2 = total_news[1000:2000].reset_index()
total_news_3 = total_news[2000:3000].reset_index()
total_news_4 = total_news[3000:4000].reset_index()
total_news_5 = total_news[4000:5000].reset_index()
total_news_6 = total_news[5000:6000].reset_index()
total_news_7 = total_news[6000:7000].reset_index()
total_news_8 = total_news[7000:8000].reset_index()
total_news_9 = total_news[8000:9000].reset_index()
total_news_10 = total_news[9000:10000].reset_index()
total_news_11 = total_news[10000:11000].reset_index()
total_news_12 = total_news[11000:12000].reset_index()
total_news_13 = total_news[12000:13000].reset_index()
total_news_14 = total_news[13000:].reset_index()

# %%
total_news_14 = pd.read_excel('2019_news_final.xlsx')

# %%
rndno = lambda: random.randint(0,255)
color = lambda: (rndno(),rndno(),rndno())

# %%
def get_tags(text, ntags=50):
    hannanum = Hannanum()
    columns = ['tag','size']
    Result = pd.DataFrame(columns=columns)
    for i in tqdm_notebook(range(len(text)//1000)):
#         print(text['제목'][i])
        nouns = hannanum.nouns(text['내용'][i])
        count = Counter(nouns)
        for n , c in count. most_common(ntags):
            total_df = pd.DataFrame({'tag':[n],'size':[c]})
        
            Result=pd.concat([Result, total_df])
    Result.reset_index(inplace=True)
    Result=Result.drop('index',axis=1)
    return Result

# %%
def draw_cloud(tags, filename, fontname='Korean', size=(800,600)):
    pytagcloud.create_tag_image(tags, filename, fontname=fontname, size=size)

# %%
total = get_tags(total_news_14)

# %%
total_1 = get_tags(total_news_1)
total_2 = get_tags(total_news_2)
total_3 = get_tags(total_news_3)
total_4 = get_tags(total_news_4)
total_5 = get_tags(total_news_5)
total_6 = get_tags(total_news_6)
total_7 = get_tags(total_news_7)
total_8 = get_tags(total_news_8)
total_9 = get_tags(total_news_9)
total_10 = get_tags(total_news_10)
total_11 = get_tags(total_news_11)
total_12 = get_tags(total_news_12)
total_13 = get_tags(total_news_13)
total_14 = get_tags(total_news_14)
# Out:
# C:\Users\Hobak\Anaconda3\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)
# ...

# %%
total
# Out:
#           tag size
# 0          일본   11
# 1          수출   10
# 2           것    8
# 3          정부    7
# 4         반도체    5
# 5          한국    4
# 6          부진    3
# 7         하반기    3
# 8          규제    3
# 9          내용    3
# 10         상황    3
# 11          수    3
# 12        동영상    2
# 13         하락    2
# 14          등    2
# 15         관련    2
# 16         업계    2
# 17         예상    2
# 18         미중    2
# 19         문제    2
# 20         이번    2
# 21         방침    2
# 22         금지    2
# 23        기업들    2
# 24         뉴스    1
# 25          ■    1
# 26      비즈플러스    1
# 27       오후토론    1
# 28        윤창현    1
# 29      서울시립대    1
# ..        ...  ...
# 620       지난해    3
# 621        국내    3
# 622        절차    3
# 623         곳    3
# 624        확정    3
# 625        주식    3
# 626   미쓰비시중공업    3
# 627      후지코시    3
# 628        처분    2
# 629         법    2
# 630        영향    2
# 631  이춘식(95)씨    2
# 632       10월    2
# 633        승소    2
# 634         뒤    2
# ...

# %%
total = pd.concat([total_1,total_2])
total = pd.concat([total,total_3])
total = pd.concat([total,total_4])
total = pd.concat([total,total_5])
total = pd.concat([total,total_6])
total = pd.concat([total,total_7])
total = pd.concat([total,total_8])
total = pd.concat([total,total_9])
total = pd.concat([total,total_10])
total = pd.concat([total,total_11])
total = pd.concat([total,total_12])
total = pd.concat([total,total_13])
total = pd.concat([total,total_14])

# %%
total.head()
# Out:
#              color  tag size
# 0    (96, 183, 35)   일본   11
# 0   (23, 211, 217)   수출   10
# 0  (175, 203, 133)    것    8
# 0    (190, 28, 79)   정부    7
# 0    (47, 62, 102)  반도체    5

# %%
total.to_excelcel('total.xlsx')

# %%
len(total)
# Out:
# 654821

# %%
result_total = pd.DataFrame(total.groupby('tag')['size'].sum())

# %%
result_total.sort_values(by='size',ascending=False).head(50)
# Out:
#         size
# tag
# 일본    107331
# 것      67535
# 등      33777
# 수      26591
# 불매운동   24935
# 정부     20195
# 한국     20081
# 이      17002
# 우리     15858
# 제품     15684
# 말      10723
# 문제      9754
# 국내      8877
# 조치      8260
# 기       7742
# 수출      7456
# 경제      7050
# 아베      6960
# 거       6882
# 기업      6784
# 맥주      6600
# 생각      6424
# 때문      6242
# 운동      6192
# 전       5980
# 브랜드     5973
# 상황      5935
# 뉴스      5718
# 저       5447
# 판매      5148
# 중       5041
# ▶       5014
# 때       4948
# 여행      4901
# 감소      4863
# 이번      4831
# 규제      4823
# 매출      4806
# 수출규제    4736
# 노선      4708
# 한       4452
# 대통령     4414
# 서울      4364
# 국민      4323
# 앞       4265
# 경제보복    4252
# 영향      4108
# 대응      4095
# 그       4089
# 일본산     4033

# %%
len(result_total)
# Out:
# 56658

# %%
result_total.to_excel('total_result.xlsx')

# %%
word = pd.read_excel('total_result.xlsx')

# %%
word.head()
# Out:
#     tag    size
# 0    일본  107331
# 1     것   67535
# 2     등   33777
# 3     수   26591
# 4  불매운동   24935

# %%
word.head(50)
# Out:
#      tag    size
# 0     일본  107331
# 1      것   67535
# 2      등   33777
# 3      수   26591
# 4   불매운동   24935
# 5     정부   20195
# 6     한국   20081
# 7      이   17002
# 8     우리   15858
# 9     제품   15684
# 10     말   10723
# 11    문제    9754
# 12    국내    8877
# 13    조치    8260
# 14     기    7742
# 15    수출    7456
# 16    경제    7050
# 17    아베    6960
# 18     거    6882
# 19    기업    6784
# 20    맥주    6600
# 21    생각    6424
# 22    때문    6242
# 23    운동    6192
# 24     전    5980
# 25   브랜드    5973
# 26    상황    5935
# 27    뉴스    5718
# 28     저    5447
# 29    판매    5148
# 30     중    5041
# 31     ▶    5014
# 32     때    4948
# 33    여행    4901
# 34    감소    4863
# 35    이번    4831
# 36    규제    4823
# 37    매출    4806
# 38  수출규제    4736
# 39    노선    4708
# 40     한    4452
# 41   대통령    4414
# 42    서울    4364
# 43    국민    4323
# 44     앞    4265
# 45  경제보복    4252
# 46    영향    4108
# 47    대응    4095
# 48     그    4089
# 49   일본산    4033

# %%
word[word['tag']=='것']
# Out:
#   tag   size
# 1   것  67535

# %%
def del_word(df,stopword):
    for i,j in tqdm_notebook(enumerate(df.tag)):
        if j in stopword:
#             print(j)
            df.drop(i,inplace=True)
    df.reset_index(inplace=True)
    df.drop('index',axis=1,inplace=True)
    return df

# %%
stopword= ['이번','◇','것','등','수','이','기','▶','거','전','저','중','때','한','앞','때문','그','일본','불매운동','◆','이날','말']
# del_word(word,stopword)

# %%
word.head(50)
# Out:
#      tag   size
# 0     정부  20195
# 1     한국  20081
# 2     우리  15858
# 3     제품  15684
# 4     문제   9754
# 5     국내   8877
# 6     조치   8260
# 7     수출   7456
# 8     경제   7050
# 9     아베   6960
# 10    기업   6784
# 11    맥주   6600
# 12    생각   6424
# 13    운동   6192
# 14   브랜드   5973
# 15    상황   5935
# 16    뉴스   5718
# 17    판매   5148
# 18    여행   4901
# 19    감소   4863
# 20    규제   4823
# 21    매출   4806
# 22  수출규제   4736
# 23    노선   4708
# 24   대통령   4414
# 25    서울   4364
# 26    국민   4323
# 27  경제보복   4252
# 28    영향   4108
# 29    대응   4095
# 30   일본산   4033
# 31    7월   4006
# 32    대표   3782
# 33  일본제품   3779
# 34    의원   3680
# 35    앵커   3654
# 36    규탄   3607
# 37    경우   3541
# 38    발언   3479
# 39    회장   3469
# 40    확산   3438
# 41    중단   3378
# 42    주장   3293
# 43   반도체   3277
# 44    미국   3274
# 45    보복   3210
# 46    제외   3206
# 47    관계   3081
# 48    시장   3077
# 49    사람   3006

# %%
word.head(50).to_excel('word_list_50.xlsx')

# %%
news_2019 = pd.read_excel('2019_news_final.xlsx')

# %%
news_2019.head()
# Out:
#    Unnamed: 0                                      제목  \
# 0           0  [오후토론] ‘경제보복’ 꺼내든 日…정부도 맞대응 움직임, 카드는?
# 1           1  한·일 무역전쟁에 불매운동 번질라…떨고있는 유니클로·데상트·아사히
# 2           2        “일본의 수출 중단 사태, 자동차 불매운동이라도 나서야”
# 3           3      “우리도 일본 제품 불매하자” 일본 경제보복에 반일감정 폭발
# 4           4  "日수출규제에 불매운동 벌어질라"···국내진출 일본 기업들 전전긍긍
#
#                                                   내용       언론사           날짜
# 0  동영상 뉴스\n\n\n\n\n ■ 비즈플러스 '오후토론' - 윤창현 서울시립대 경영...  SBS CNBC  2019.07.01.
# 1   "영향 제한적" 기대하면서도…과거와 다른 분위기에 '우려'↑© News1 이은현 ...       뉴스1  2019.07.02.
# 2   전문가 “일본의 한국 수출 중단 사태 6개월 이상 지속될 듯”성윤모 산업통상자원부...      한국일보  2019.07.02.
# 3   “일본 관광 6개월만 끊자” 격앙… 일각 “똑같은 짓 삼가야”지난 1일 나가미네 ...      한국일보  2019.07.02.
# 4   "日규제 발동 근거 명확지 않아"靑 언급자제...정책실 '비상체제'강경화 "상황보...      서울경제  2019.07.02.

# %%
hankyung = news_2019[news_2019['언론사']=='한국경제']
maekyung = news_2019[news_2019['언론사']=='매일경제']
chosun = news_2019[news_2019['언론사']=='조선일보']
joongang = news_2019[news_2019['언론사']=='중앙일보']
donga = news_2019[news_2019['언론사']=='동아일보']
hankyure = news_2019[news_2019['언론사']=='한겨레']
kyunghyang = news_2019[news_2019['언론사']=='경향신문']

# %%
news_list = [hankyung, maekyung, chosun, joongang, donga, hankyure, kyunghyang]

# %%
def reindexing(df):
    df.reset_index(inplace=True)
    df.drop('index',axis=1,inplace=True)
    return df

# %%
for i,j in enumerate(news_list):
    reindexing(j)
# Out:
# C:\Python\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
hankyung
# Out:
#      Unnamed: 0                                                제목  \
# 0            26       [조재길의 경제산책] "일본의 2차 타깃은 반도체 장비"…'한방' 없는 한국
# 1            58                                  日 경제 보복에 뿔난 시민들
# 2           118                  일본 불매운동 불똥 튄 이시언, 지인 방문이 무슨 죄라고
# 3           122             일본 불매운동 번지는데… 이시언 SNS 여행사진 올렸다 '화들짝'
# 4           129                    모나미, 상한가 기록…일본 불매운동 수혜주로 '주목'
# 5           143           한국 수출 규제에 '일본 불매운동' 확산…트와이스·아이즈원에 '불똥'
# 6           158            반도체로 당한 보복 반도체로 되갚을까…일본에 상응조치 예고한 홍남기
# 7           184       아베 무역보복 개시…일본 네티즌 "한국 분수도 모르고 초대국 일본에 까분다"
# 8           185      [이슈+] 누워서 침 뱉는 일본?…한국서 잘 나가던 자차(自車)에 '브레이크'
# 9           240                중소상인·시민단체·네티즌, "일본산 제품 불매운동" 한목소리
# 10          243              일본 불매운동에 트와이스 사나 퇴출요구? 하태경 "참 어리석다"
# 11          255               모나미·신성통상 '일본 불매운동' 수혜주 기대감에 치솟는 주가
# 12          260                  '일본 불매운동' 겨냥한 탑텐? 유관순·김구 티셔츠 공개
# ...

# %%
def get_tags(text, ntags=50):
    hannanum = Hannanum()
    columns = ['color','tag','size']
    Result = pd.DataFrame(columns=columns)
    for i in tqdm_notebook(range(len(text))):
#         print(text['제목'][i])
        nouns = hannanum.nouns(text['내용'][i])
        count = Counter(nouns)
        for n , c in count. most_common(ntags):
            total_df = pd.DataFrame({'color':[color()],'tag':n,'size':c})
        
            Result=pd.concat([Result, total_df])
    return Result

# %%
news_list = [hankyung, maekyung, chosun, joongang, donga, hankyure, kyunghyang]
hankyung_word = get_tags(hankyung)
maekyung_word = get_tags(maekyung)
chosun_word = get_tags(chosun)
joongang_word = get_tags(joongang)
donga_word = get_tags(donga)
hankyure_word = get_tags(hankyure)
kyunghyang_word = get_tags(kyunghyang)

# %%
hankyung_word.head()
# Out:
#              color tag size
# 0  (181, 158, 131)  일본   20
# 0    (89, 19, 163)  수출   12
# 0   (242, 49, 159)  우리   11
# 0   (64, 196, 148)  정부    8
# 0    (82, 84, 125)   등    8

# %%
stop="절때 장 바 선 금 참으로 참말로 실어 볼 대해 치 절때 절대 볼 것 완구 말 것 더 습 대한 우린 설 무조건 나 불성 의 저런 무슨 승 점 경우 설 나 무척 극우 은 쪽 짝 너 점 대한 살 것 볼 외 나 명 농 피 큐어 더 이상 짓 의 씨 고함 니 내 임 게 석 색 것 덜 겟 고 알 제 고 이 리나 개월 이상 건가 분 공 디옷 정 인벤 전인 분 개 것 읍 더 압니 옆 온 라며 사 러신 거 래서 제제 명 뭐 진짜 나 것 현 어변 별로 아마 머 이 절대 된거 비 그닥 이 고요 참여 끈 커녕 더 롯  스스로 자  충 설 간의 행 용 수 명 고서 꼭 내 머그 함 은 곤 등 쥐 좀 이기 때문 더 행 왈 이번 쭉빵 볼 것 이후  중국  빛 호 이번 주리 번 적 안 변국 줄 것 맥 이면 원래 아 토 렌트 오히려 안 술술 입 뽕 첩년 다해 며 뭔가 모 씨바 주어 점 중 위 아더 월드 스레 이 대해 것 뭐 기 록 이참 꿀쇼 님 임 온통 그 한적 판 편 응 일 본답 사 란 수 것 위해 어쩌면 등 재 인유 튜 린거 웅거 웅앵 룸빵 롤 데 개 벌 시 주 홀 거 망 려 로 컨 그것 두 번 적지 놀 가까이 만약 여기 것 붐 씨포 카 등 연 듯 발발 위 코 또 거 못 거 총 간 악의 품 저열함 신민 지금 고 식 발 걸 볼 수 좀 작작 건가 들엇겟습 은 전 것 및 빵 등 류 뿐 안 간다 못 니 끼리 이  배상하 덜 것 대한 달 쇼들 거 걸 살 맙시 하내 빨 제 분 녀 점 때 이제 사지 어쩌 갈수록 역 정준 이변 이제야 갈수록 짓 선   이  깨 참으로 가면 컷 화 데 뚝 똘똘뭉쳐 품 산 어제 더 서도 대해 쳔 드 어쩌구 더더 더 한당 급 가득 령 좌 폐 도통 함 더 열 것 덕인 듯이 어쩌란말임 매 합시고 나가야 랍니 잡 뫄님 거외 티나 앞서 겨냥 쩌러 정말 뿐   무치 약간 피북 마 리지 메 마다 확 몇몇 하하 일삼 프레 시안 갖은 끌 젠 틤 죽 먹기 무려 불타 나 적 준 얘 그거 일이 화이 투 번진 란 오라 칠 짓 제발 뿐 이 만큼 작살 내야 함 선 임 더욱 활활 다음 보편 이 우매 파시즘 땐 신 이  그 뚝 데 일리 거나 더욱 핫 터 도 슬슬 보지 싹 탈 초 범 고마 무지   어쩌 둘 두 심 상치 의 현 더 빤짝 섬 더 궤변 증빙 시 및 터 도 라카 더욱 특 팔 최 실 대한 웩 자 또한 슬슬 치 중 님 화 고서 산 엌케 사 스웨 트 준 분 저 타령 로 아뇨 모로 제대로 알 대신 차고 폄훼 때 더욱더 능 명 택하 남 아예 자유자 무참 건 이전 더 수 초 등등 내겐 차라리 좀 놈 머 함 본기 롯 땜 자 님 롯 본기 대해 과 군속 둘겨 완전 섬멸 리즘 증빙 안이 특 나기 엮는글 당한 하란 없드 쿄애니 꿈틀  대한 등 개 뚝 꼭 댓 니 터 도 핫 더욱 부 제 정말 니 오브 이 수록 더 것 뎅   등 것 생각 나선 후  일 요 이 짓 염상  며 북 못 얼마나 취합해 하라 며 더 다음 게 도 간 접 이후 폐간 보 전 밒 좀  론 빨 손안 더 일이 그른 남 저 중이 단 번 제 일 대해 단 번 제 피하 더 내 바로 위 껏 해 간자 이 뭣 난 누리 게 빠 애 때 이 빵빵 데 거 이 과 좀 하자 똘똘뭉쳐 스엠 우리 수 짓 해 발 머 시벌 능이 율 홍 좀 좆 리 버럴 라며 내 단 임 보 나 번쩍 자 한당 바 미당 글렀다 거 품 모두 벌써 머 낯낯 자 정말 하물며 할 게 거 안 건 최 하위 등 뒤 온 터 도 이해해 짝 짝짝 튀어 애기 독재정 잔뜩   떄 어쩌노 그동안 니 안  그동안 니 안 질 그냥 안사면 다 그 어디 무슨 고 곳도 고 오 단 중 모 이제 산다 몰래 창 얻지 업 더 뿔 등 온 최고 내 때문 임 나 약 대체 속 머 자 초 이 벌써 를 짓 각자 온 눈 늘 말 란 제일 함 가장 중 휩 및 그 리 곡 예전 분 애 보지 걸 해 뒤 바 부쉈습니 바 류 배 게 이제 관련 엮으실 이 채 비아  계 편 쏜다  어이 만하 티 안 개 삼 폄 맘 함 년 병 걸 속 등 종일 하루 통 아주 추후 뿐 오히려 번진  당장  향 것 저 먼저 기전 치 이 기껏 유 초 점점 칠 콧 웃음 안 간다 이참 정도 부터 민 거기 게 음 근처 거 관 아예 속 바 쭈 욱 다른  전 국 그 당시 건 실맹입뉘뒈 비쉿하눼예 땜 속 보 말 저 보 쌤쌤 어디 정 분 것 저 이제 방사 능 아주 친 것 달라 또 다른 쩍 던 최대   안 거 해 간 게 제 바로 뉴 스랍 니 일어나고 또박또박 유티 다시 일만 쟗 줄자 띠 참나 컨 식지 서도 반드시 스랍 푸비캐캬캬컄  엑쬬옵항들  머갈  거릴 듯 건 곀 게다 롸 치 답시고 노오 숫 가락 섯다 말나 먼저 듭니 의  질 그냥 안사면 다 그 어디 무슨 고 곳도 고 오 단 중 모 이제 산다 몰래 창 얻지 업 더 뿔 등 온 최고 내 때문 임 나 약 대체 속 머 자 초 이 벌써 를 짓 각자 온 눈 늘 말 란 제일 함 가장 중 휩 및 그 리 곡 예전 분 애 보지 걸 해 뒤 바 부쉈습니 바 류 배 게 이제 관련 엮으실 이 채 비아 거릴 듯 건 곀 게다 롸 치 답시고 노오 숫 가락 섯다 말나 먼저 듭니 의   중 명 고이 층 거 라며 이제 계속 저 다가 여기 때 과연 디 무슨 명 처 이 거 난 애 더 저 제 여개 니 노노 임 더 요 분 바 속 때 원 키 과 습 리 줄 피우지 휩  카 율 명 자고 임 정도 일 줄 안 연 당분간 가라 난리 밥 어쩌 명도 개꿀 쫄았다고해 먹듯 모조리 페 곧 앑 흠 업계 폐 특별  것 그 때 질 것  중 행 열 것 팩 말 건 그냥 너 데 살 대한 산 내 도 깜놀 발 누가 당신 어찌 다만 게 달 세비 공 것 때문 세븐 틴 곳 방사 능 매우 곳 팬 면서 꼴 보고 저 코 쭉 안 덕 더 느그 한멤 티 내지 정말 해 주심 레야 밍 등 수 분 템 하라 나 똥 거 대체 전 안 정도 라서 또 거기 무슨 하니 민 뭐시기 안해 산 안타 약 비록 범 깨달 뎅 안 사 질 눈 사려 등 이번 낌 우린 줄 부터 거 뭐 세 씨 이 바시 위해 이 아무 목 막 싹 말 수가 퇴 이번 길 거 스르 위해 뭐꼬 산 명 란마 요 매콤 또 건 뭐 니 어디 빙 신들 나 홀로 년 전 인 상이 더 이번 고작 습 아주 환 이 판 아주 저희 탓 거 니 번 섭읁틶 를 돌이 위 님 알 에프 의 분 계속 피나 더 층 행 부어 배밖 겨 댘 편 이참 힌거 위함 그깢 푼 못거시 힘 내 듯 날 안 사 이후 맙시 자 뼈 층 거 필욘 졸라 영 거 저 섬 번지 아주 점 간다 나섯는데 맘무 언니 이나라 다른 폰 부어 볼때 조금 온 노노 모 보이 그룹 과연 좌 때 망 정도 불매운동 좀 책 게재 그거 주지 파 옹 김 완제 테 겸 션 커녕 쭉 능이 금일 어쩌면  정말 말  꼴  님   남 지금 차라리 가지 갑자기  홀로  닥치고 쉬키 뜻밖 시 노노 개 이번 무너 리기 위 더욱 진짜 이 단 번 적 꽤 그냥 고 왜앖냐 똘추 아하 땜 시발 원 진짜 막방날 삼백만 린것 퍼트  그게 마냥 빼액 너 그거 마냥 꼴 빅스 젤피 폄훼 엑스 그냥 스스로 님 도 오점 후 둘 진짜 조차 난 좆 애 내 더 애 생일도 좀 중 아아 한지 얼마 게다가 울 기 보내락오 수 말 대해 것 늘 식이 게다가 명 스 병 또 이 안 대한 분 고 뭐 자마자 이 가야 방사 능 도 빡 대가리 그냥 듯 그대로 용지 어 더니 자 조파 난 애 내 더 좀 중 아아 한지 얼마 게다가 가즉   왜왜오    더 좀 계속 왜오 왜왜왜 왜 진심 아아 한지 얼마 게다가 울 기 대해 늘 명 자고 뱃삯 당장 뭐 진짜 대체 황 섬 아마 위해 차 타고 막 회근 애 심지어 겹 난린데 그거 거 안 일도 아무 안 거 서치 홍 대신 초 중 고 자 국 이 남 입 란 누차  제 공 노노 노노노 네 정말 무조건 옥 티 제 니 이제 주겄다 북 입 삭    알 뭐 정액 입싹 걱 그냥 애초 기 이제 존나 꼬 라지 듯 타 쟤  안 대요 거기 더 협엽 등 뿐 사인 대체 무슨 그 나 니 개  물어 걸 이  것  이제 로서 뻔 햐 것 빰맞 넙치 산 등등 뭐 파나소닉 게 깨달 되 비넌 반도 체 안 하나 대 업도 부수 재 쟈 구해 절린 좆 접 역 겨우 것 줏어먹 좆돌 백두대간 쇠말뚝 대강 젖줄 초계기 해공 장악 지열발 땐 어켜 봣대 그거 부터 보지 나 고치 사죄 그것 팀쿡 걸 알 나 중임 후 내 산 및 등 엎 여기 산 재파 것 절대 요 좀 또 플미 쪽 탓 그스 더  것 거 말 인 욱 글 키 민 이제 겨 심상찮 배 민 팔 바로 삼 맙시 단교  춍 넷우익 장하나 수역 국 라며 사서 듯 율 알 더 손 것 투 렉 사스 내 등등 사지 맙시 시파 못 계 롸 심상찮 빼 이 민 사이 급 팔 여쨎던 시 바리 염치 해 닙 불 리 니콘 보 생각 하 때 시 등등 기 리 등 다른 니 것 뿌리 넌 말  무조건    일어나고 수만 여 일 아스트로 로 이세 시금 일이   위 놈 모두 안해 좌 시해선 못 안 불면 꿀 등 하든 앞 데   안 스노우 혐기 앱 업 데 연일 앞 안 불면 난 재해 관방 내 퇴 진짜 곳 해 다변 결코 꼬 라지  키 아주   땐 어케 봣대   팀쪽 언릉 아마 난후 절대 안감 린 중임 사은 품 아예 산껀 주어 작년 벌 이참 노리 춍 투 콜 걸핏하면 카 경우 기린 리 리나 불면 체 신닛테쓰 마쓰 만하 자기 심상찮   어쨎거  닙   기린 리 커서 면 벌써   때 그 사람 더 내 봉 산  내 라인  함  가지 후지 실컷 저번 달 빼빼 실컷 외치 더 접 선 뭐 모두 식 론 외치 바치 자고 실트 틔터 막콘가 아미 좀 뷰임 애 아미가 가끔 하니 살 단교 수 놈 말 로 겨 인 비  순간   등   은 내 어이 놧더 놈 싹 간다 놈 이건 디 플레디스 한성수 니 짓 때 니 네 니 거나 말랜다 카풀따윌해 그 더 좀 누가 그거 더 줔 덕 씨디 굿 도 페도 몇 년 후 때문 내 기선 듯 수 번질 더 하렵니 저 중이 동포 개또  라이 혹시 이면 응모 안할껀데  서하면 등 것 만 이번 애초  및 가의 뭐 또 아미 메일 무시 겨우  등 바 싹 수 것 이제 니 맥널 재 의  그거 보고 또 셈 메박 자 지용 민 다 뭐 뭐시기 셈 안 과 꼭 뭐 다른 주위 도리 석 영해 뭐 깃발 대니 일 일어나지 대체 얼마 스  를 손 절하 저번 니 일 햐 니 한번 둣습 시절 니 좉본 해 이후 하라 뷰잉 오 거 쪽 뿐 하자 예시 유 도 안팎 수록 척 곡 것 게 보 이 전 공카 그게 안 이 이번 답 더 애 나 때 얘 거 피 순 땜 주 더 나 아미 아키 찰로 브이 앱좀 요 가장 공 이번 수 일 내 언찰 갑 내 내의 대한 해도 이기 때문 압니 부디 만약 긍 데 애 디마 난 뭐 어디 제발 스밍 애 상 스밍 도 것 그 및 물 전 안 통 젤 단연 그룹 색  때 산지 쪽 단 니 짓 망치 난 내 티스 트 지금 이번 거기 무머 협업 이  판 보 저 그 멍 진짜 청도 바변 노구교 각종 중 동북 안 이 데 장악 토건 족 의  정 비 은 야적 박 서 맥 쿼리 솔찍 마이너 쩍 버 꽤 구 것 회 등등 이 암만 해 최저  것 해 플텍 나왔는데 줄 거나 놈 요 열 되 일보 중앙 클린 징 오일 한적 그냥 고 피 산 자발 적 어이 것 좀 아작 껄스러운 행 거리 거 못 이건 중이 삥 누구 파사트 산 율 거 답 반 호 온 왈 거 질 산채 언급 것 그 말 로서 것 자체 맘 안 중 모 하필 미면 나 벨 거 즈음 몸 강 것 부분 극 재해 및 수아 라모 페덱스 지난 가장 토  라모 합 그낭 로서 러이 모 들 건 내나라 난 것 지껄였던 대한 뭔가 생 컴 뜻 것 역산 데 의  촉수 모 러이 안 껏 여지 함 이 뎅 댁 살 거   얼마난 살 후 로만 것 보더 일이 쇼락 패 ㅎ최 업글킷 하니 대해 하렵니 다 왜 석 달 관함 단 땜 뺑뺑 오히려 다 치명 긍 디마 어디 제발 슬모 번 스밍 왜 그냥 해시 맘 맘에들면 보편 각 아웅산수치 킹갓 워 블 언제 가든 뻘 과연 오늘 빻았으 벌벳 사면 쇼 포 짓 그냥  덤덤 듭니다 설마 및 라모 수아 관 짓 족 크게 레이 조슈아 콱 님 사이 및 니 껏 따위  이문 동안 번지 려 뎅 대부분 가장 지점 일원 로만 싱하 쿡 보더 뽀뽀 씌 죄 댓  좀더  달라 가즈 어디 사시 급 에 신고   중 말 위 계 하리 나 앞 놈 좀 베 폐기 여전 맙시 론 내 뭐 제대로  일 불매운동 일 를 더 이상 보고 선 이제 게 일본 이제 익금 거의 의 함 맙시 오픈 상대로 인분 이제 발끈  좀 누 짐  머루 기 원 끼리 굳이 노 존 대해 좀 예 노 존 곳 알 최소한 말로 더욱 재 맙시 쫄딱 위 똘똘뭉쳐  제 서치 잡고 더 이상 발 폐쇠 극력 더욱 세진 리콜 어쩌구 대요 세 이하 심 곳 이제 이전 함 퇴 금은 마자 이 말 응 내 뭔가 마치 지지 것 줄 실컷 접 외치 하니 적극 보통 마하 끼리 서로 작 대 정작   살 개   애 아미가 가끔 모든 통 정말 뭥미 콘 햏으 더욱 바란 응 뭔가 마치 지지   하든 뭘 일어나서 별로 안 걸 불티 볼 그 회 다운 무니 로 환시 몇 이 때 저 그 여기저기 식 최소 분 그 뭘 하든 이 난이 것 말 곳 거기 꼴 여기저기 불매운동 일본 쪽 웹 처럼 위해 어용 국 론 내 보기 용신 좀 눈 게 해도 팔면 이건 사 선 거 돌림 의 를 너희 고고 며 숨 내 잉께 똑 바리 는걸 이 퇴 수 무니 수가 등 음 화가 더 끼 친 월드 자이언츠 거의  안 려고 돌 중 들 남 심 상치 망치부인 고대 피빨 원 앞 요즘 스레 알 수가 읍 게 더 화가 나 나 신들 망 통해 본격 밀레 점 겹합 새 단장 트 레비 광돈 요즘 스레 요 초 대한 모 속 아무 걸 사나 늘 당하 심 은근 이심 외 신더 레나 줄 알 재 강 만 전 류  보이 콧등 대한 바이 못햇 듀 로 위해 니콘 다이지 질 제일 소스 바 저런 정도 엮어 초 여 의 세 잠 세단 풀 소립 다만 게봄 꽤 꼭 여러분  걸 계속 거의 내  이후 모두 본계 또한 이 구장 분 적 은 간 내 등 은  망겝시 뒤 하나 걸 로리 이 막 수 건 합 자라 더 다음 것 건가 뿐 불 머임 방 능 좌좀 적 호 내 버 최 실과 거 자가 그 둘 버니 호 등 대해 그 아 확연 진짜 정도 지 봣 이 짗 기전 좀 전 나이 츠 오시 그다지 게 것 한번 좀 함 새 끼 끼덕 봇 이 듯 전 웹 지사 면서  의 등등 엉엉 이외 씨 비  함 임 그 애초 머 뭐 알 아들 것 주 무슨 좀 하나 너 기 글쎄 단독 이처럼 인걸 본적 파니  기 중 애 무 애 해  이노 배웟 역시 그 전 때문 이 게 더더 저 더치 향 것 설령 후 이제 후 고 지누 유분수 후 거 던 윙 거 던 금 소연 안고 게 두 손 헤럴 시 털  판  댕청 중 보  쪽 년 두 배 어기 어기 골 놈 척 놈둘 거나 서브컬쳐 중 햇 빼 수 잘만 해줫어 쥇겟 뚝 끝내 썩 하라 난 옥 등 옥시 애꿏 자 이지 평생 발견됫음 북괴 이떄 것 걸 쇠 일어 것 옥 사거 따름 이 말 일인 거 똑바로 여 아닥한다 조던  에어  빼 를 로 저 거 순간 그 제 대 위 때 데 임 니콘  세운 편 대대로 이번 제 못 간 안  제 마눌 몇 변  "

# %%
asd = stop.split(' ')

# %%
del_word(word,asd)
# Out:
# ...
# 우리
# 생각
# 경우
# 사람
# 중국
# 이후
# 관련
# 일
# 내
# 부분
# 참여
# 업계
# 데
# 정도
# 이상
# 두
# 오늘
# 주
# 대
# 점
# 반
# 그것
# 얘
# 글
# 나
# 지
# 명
# 책
# 들
# 가지
# 달
# 원
# 번
# 식
# 면
# 당시
# 속
# 행
# 시
# 개
# 차
# 지금
# 만
# 뒤
# 간
# 곳
# 뭐
# 저희
# 적
# 네
# 위
# 후
# 신
# 최대
# 힘
# 뜻
# 씨
# 만큼
# 사죄
# 여기
# 어제
# 깃발
# 작년
# 약
# 그룹
# 리
# 사이
# 자체
# 언급
# 줄
# 하나
# 벌
# 노
# 국
# 적극
# 초
# 다음
# 극우
# 쪽
# 자
# 뿐
# 분
# 계속
# 답
# 눈
# 할
# 하루
# 거리
# 안
# 진심
# 투
# 유
# 동안
# 거기
# 바
# 상
# 대체
# 대부분
# 박
# 파
# 장
# 누구
# 편
# 여러분
# 길
# 방
# 날
# 북
# 그동안
# 강
# 손
# 웹
# 예
# 게재
# 지사
# 최
# 앱
# 여
# 입
# 폐
# 이전
# 보
# 각종
# 듯
# 지지
# 불
# 외
# 순
# 해
# 채
# 작
# 화
# 비
# 황
# 도
# 지점
# 탓
# 남
# 자기
# 이하
# 구
# 요
# 겨냥
# 오
# 물
# 오픈
# 홍
# 특별
# 부
# 사
# 세
# 배
# 몇
# 최고
# 예전
# 협업
# 프레
# 선
# 어디
# 확
# 무시
# 년
# 당신
# 한번
# 극
# 셈
# 아키
# 제
# 얼마
# 테
# 아마
# 발
# 모두
# 진짜
# 의
# 다
# 뉴
# 뭔가
# 모
# 막
# 옆
# 단독
# 서로
# 몸
# 세단
# 웃음
# 시절
# 아들
# 통
# 짓
# 건
# 라인
# 그거
# 창
# 합
# 금
# 스
# 재
# 총
# 연
# 오일
# 걸
# 고
# 근처
# 판
# 각
# 각자
# 돌
# 요즘
# 정
# 관
# 너
# 최소
# 김
# 만약
# 다운
# 가득
# 겸
# 안팎
# 층
# 장악
# 곡
# 완전
# 언제
# 터
# 망
# 병
# ...

# %%
word.head(100)
# Out:
#        tag   size
# 0       정부  20195
# 1       한국  20081
# 2       제품  15684
# 3       문제   9754
# 4       국내   8877
# 5       조치   8260
# 6       수출   7456
# 7       경제   7050
# 8       아베   6960
# 9       기업   6784
# 10      맥주   6600
# 11      운동   6192
# 12     브랜드   5973
# 13      상황   5935
# 14      뉴스   5718
# 15      판매   5148
# 16      여행   4901
# 17      감소   4863
# 18      규제   4823
# 19      매출   4806
# 20    수출규제   4736
# 21      노선   4708
# 22     대통령   4414
# 23      서울   4364
# 24      국민   4323
# 25    경제보복   4252
# 26      영향   4108
# 27      대응   4095
# 28     일본산   4033
# 29      7월   4006
# ..     ...    ...
# 70      역사   2215
# 71      방송   2183
# 72      문재   2159
# 73      진행   2152
# 74      내용   2131
# 75    한국콜마   2110
# 76    기자회견   2085
# 77      소재   2080
# 78       ▲   2046
# 79      양국   2025
# 80     판매량   2019
# 81      보도   2011
# 82    우리나라   1975
# 83      올해   1972
# 84      8월   1959
# 85      오전   1947
# 86      발표   1916
# 87     시민들   1916
# ...

# %%
word.to_excel('2019_news_word_list.xlsx')

# %%
def size_sum(df):
    result = pd.DataFrame(df.groupby('tag')['size'].sum())
    return result

# %%
news_word_list = [hankyung_word, maekyung_word, chosun_word, joongang_word, donga_word, hankyure_word, kyunghyang_word]
maekyung_result=size_sum(maekyung_word)
hankyung_result=size_sum(hankyung_word)
chosun_result=size_sum(chosun_word)
joongang_result=size_sum(joongang_word)
donga_result=size_sum(donga_word)
hankyure_result=size_sum(hankyure_word)
kyunghyang_result=size_sum(kyunghyang_word)

# %%
maekyung_result.sort_values(by='size', ascending=False).head()
hankyung_result.sort_values(by='size', ascending=False).head()
chosun_result.sort_values(by='size', ascending=False).head()
joongang_result.sort_values(by='size', ascending=False).head()
donga_result.sort_values(by='size', ascending=False).head()
hankyure_result.sort_values(by='size', ascending=False).head()
kyunghyang_result.sort_values(by='size', ascending=False).head()
# Out:
#      size
# tag
# 일본   1999
# 것    1224
# 등     675
# 수     560
# 한국    553

# %%
maekyung_result.to_excel('2019_maekyung_word.xlsx')
hankyung_result.to_excel('2019_hankyung_word.xlsx')
chosun_result.to_excel('2019_chosun_word.xlsx')
joongang_result.to_excel('2019_joongang_word.xlsx')
donga_result.to_excel('2019_donga_word.xlsx')
hankyure_result.to_excel('2019_hankyure_word.xlsx')
kyunghyang_result.to_excel('2019_kyunghyang_word.xlsx')

# %%
def del_word(df,stopword):
    for i,j in tqdm_notebook(enumerate(df.tag)):
        if j in stopword:
#             print(j)
            df.drop(i,inplace=True)
    word.reset_index(inplace=True)
    word.drop('index',axis=1,inplace=True)
    return df

# %%
for i,j in enumerate(stopword):
    asd.append(j)

# %%
total_word = pd.read_excel("kyunghyang_final.xlsx")

# %%
total_word.head()
# Out:
#   tag  size
# 0  한국   553
# 1  정부   427
# 2  문제   272
# 3  아베   245
# 4  제품   184

# %%
stop = ['것”','‘노','한겨레','‘일본','이름','한다”고','<한겨레>','윤','“한국','이달','”','동아일보','―','지난달','뉴스','"한국','한·','조선일보','일부','전년','동영상','기자','오후','올해','오전','“일본','2019.','1','▲','매일경제','지난해','4','연합뉴스','가운데','한국의','주요','출처','7월','6월','8월','필요','전체']

total_word=del_word(total_word,stop)

# %%
total_word.reset_index(inplace=True)

# %%
total_word.drop('index',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-771379e39ac7> in <module>
# ----> 1 total_word.drop('index',axis=1,inplace=True)
#
# C:\Python\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\Python\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
total_word.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-60d50f1908b4> in <module>
# ----> 1 total_word.drop('Unnamed: 0',axis=1,inplace=True)
#
# C:\Python\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\Python\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
total_word.loc[total_word['tag']=='문재','tag']='문재인'

# %%
total_word=size_sum(total_word)

# %%
total_word=total_word.sort_values(by='size', ascending=False)

# %%
total_word.to_excel('2019_kyunghyang_word_final.xlsx')

# %%
total_word.head(90)
# Out:
#        tag  size
# 0       한국   553
# 1       정부   427
# 2       문제   272
# 3       아베   245
# 4       제품   184
# 5       조치   184
# 6       맥주   148
# 7       서울   144
# 8     수출규제   128
# 9       영화   108
# 10      경제    99
# 11      대응    97
# 12      기업    95
# 13     브랜드    94
# 14      매출    93
# 15      국회    89
# 16     관계자    86
# 17      국내    85
# 18      상황    84
# 19      제외    81
# 20      여행    78
# 21      판매    76
# 22      국민    75
# 23      미국    75
# 24    경제보복    74
# 25      비판    74
# 26      정권    74
# 27      감소    70
# 28      역사    69
# 29      양국    68
# ..     ...   ...
# 60      교수    42
# 61    전범기업    42
# 62      결과    40
# 63      취소    40
# 64     판매량    40
# 65     학생들    40
# 66     기업들    39
# 67      본사    38
# 68      상품    38
# 69     할머니    38
# 70      기간    37
# 71      북한    37
# 72      시민    37
# 73      인기    37
# 74     일본인    37
# 75      금지    36
# 76    원내대표    36
# 77      조선    36
# 78      교류    35
# 79     반도체    35
# ...

# %%
maekyung_result.reset_index(inplace=True)
hankyung_result.reset_index(inplace=True)
chosun_result.reset_index(inplace=True)
joongang_result.reset_index(inplace=True)
donga_result.reset_index(inplace=True)
hankyure_result.reset_index(inplace=True)
kyunghyang_result.reset_index(inplace=True)

# %%
maekyung_result = del_word(maekyung_result,stopword)
hankyung_result = del_word(hankyung_result,stopword)
chosun_result = del_word(chosun_result,stopword)
joongang_result = del_word(joongang_result,stopword)
donga_result = del_word(donga_result,stopword)
hankyure_result = del_word(hankyure_result,stopword)
kyunghyang_result = del_word(kyunghyang_result,stopword)

# %%
maekyung_result.to_excel('2019_maekyung_word.xlsx')
hankyung_result.to_excel('2019_hankyung_word.xlsx')
chosun_result.to_excel('2019_chosun_word.xlsx')
joongang_result.to_excel('2019_joongang_word.xlsx')
donga_result.to_excel('2019_donga_word.xlsx')
hankyure_result.to_excel('2019_hankyure_word.xlsx')
kyunghyang_result.to_excel('2019_kyunghyang_word.xlsx')

# %%
maekyung_result.sort_values(by='size', ascending=False).head(50)
# Out:
#      tag  size
# 4     한국   631
# 6   매일경제   563
# 8     정부   436
# 9     제품   424
# 10    국내   331
# 11    기업   293
# 12    맥주   254
# 13   브랜드   234
# 15    매출   218
# 17    경제   206
# 18    수출   200
# 19    조치   196
# 20    7월   185
# 22    감소   169
# 23    문제   165
# 24    대비   165
# 25    판매   151
# 26    여행   143
# 27    규제   132
# 28    한일   131
# 29    아베   130
# 32    회장   125
# 33    상황   124
# 37    보복   117
# 36   지난해   117
# 39    시장   112
# 41    매장   112
# 42   대통령   111
# 45    대응   107
# 46    미국   105
# 48    노선    96
# 49    영향    95
# 50    국민    95
# 54    주가    94
# 53   반도체    94
# 52    운동    94
# 51    관계    94
# 55   지난달    93
# 58   유니클    92
# 59    올해    92
# 60  수출규제    90
# 62    교수    87
# 63    서울    86
# 64   편의점    86
# 65    양국    85
# 66   관계자    84
# 68    증가    83
# 67    전년    83
# 69    중단    82
# 71    확산    82

# %%
maekyung_result.loc[maekyung_result['tag']=='유니클','tag']='유니클로'

# %%
maekyung_result = pd.read_excel('2019_maekyung_word.xlsx')

# %%
maekyung_result.head(50)
# Out:
#     Unnamed: 0   tag  size
# 0            4    한국   631
# 1            6  매일경제   563
# 2            8    정부   436
# 3            9    제품   424
# 4           10    국내   331
# 5           11    기업   293
# 6           12    맥주   254
# 7           13   브랜드   234
# 8           15    매출   218
# 9           17    경제   206
# 10          18    수출   200
# 11          19    조치   196
# 12          20    7월   185
# 13          22    감소   169
# 14          23    문제   165
# 15          24    대비   165
# 16          25    판매   151
# 17          26    여행   143
# 18          27    규제   132
# 19          28    한일   131
# 20          29    아베   130
# 21          32    회장   125
# 22          33    상황   124
# 23          36   지난해   117
# 24          37    보복   117
# 25          39    시장   112
# 26          41    매장   112
# 27          42   대통령   111
# 28          45    대응   107
# 29          46    미국   105
# 30          48    노선    96
# 31          49    영향    95
# 32          50    국민    95
# ...

# %%
maekyung_result=size_sum(maekyung_result)

# %%
maekyung_result.sort_values(by='size',ascending=False)
# Out:
#                size
# tag
# 한국              631
# 매일경제            563
# 정부              436
# 제품              424
# 국내              331
# 기업              293
# 맥주              254
# 브랜드             234
# 매출              218
# 경제              206
# 수출              200
# 조치              196
# 7월              185
# 감소              169
# 유니클로            166
# 문제              165
# 대비              165
# 판매              151
# 여행              143
# 규제              132
# 한일              131
# 아베              130
# 회장              125
# 상황              124
# 보복              117
# 지난해             117
# 매장              112
# 시장              112
# 대통령             111
# 대응              107
# ...             ...
# 관건"GS25           1
# 유통·패션업계           1
# 유지                1
# 유정화               1
# 공항별               1
# 과거청산              1
# 과자·음료·소스류         1
# 유사                1
# 과정                1
# 과학기술정보방송통신위원회     1
# 유명한               1
# 유림                1
# 유럽수입차             1
# ...

# %%
maekyung_result.reset_index(inplace=True)

# %%
maekyung_result = maekyung_result.sort_values(by='size',ascending=False)
maekyung_result.reset_index(inplace=True)

# %%
stop = ['매일경제','지난해']
maekyung_result = del_word(maekyung_result,stop)
# Out:
# ...
# 매일경제
# 지난해

# %%
maekyung_result.drop('index',axis=1,inplace=True)

# %%
maekyung_result.reset_index(inplace=True)

# %%
maekyung_result.reset_index(inplace=True)
maekyung_result.drop('index',axis=1,inplace=True)

# %%
maekyung_result.head(100)
# Out:
#      tag  size
# 0     한국   631
# 1     정부   436
# 2     제품   424
# 3     국내   331
# 4     기업   293
# 5     맥주   254
# 6    브랜드   234
# 7     매출   218
# 8     경제   206
# 9     수출   200
# 10    조치   196
# 11    감소   169
# 12  유니클로   166
# 13    문제   165
# 14    대비   165
# 15    판매   151
# 16    여행   143
# 17    규제   132
# 18    한일   131
# 19    아베   130
# 20    회장   125
# 21    상황   124
# 22    보복   117
# 23    매장   112
# 24    시장   112
# 25   대통령   111
# 26    대응   107
# 27    미국   105
# 28    노선    96
# 29    국민    95
# ..   ...   ...
# 70    해외    54
# 71    상품    54
# 72    주장    52
# 73    취소    52
# 74    행사    51
# 75    의원    50
# 76    사과    50
# 77    결정    50
# 78   상반기    49
# 79  소비자들    49
# 80    회의    49
# 81    비판    49
# 82   온라인    48
# 83   서비스    48
# 84    국회    48
# 85    기간    48
# 86   화장품    47
# 87    하락    47
# 88  기자회견    46
# 89    교류    46
# 90    발표    46
# 91  일본제품    46
# 92    철회    45
# 93    악화    45
# 94    방송    45
# 95    구매    45
# ...

# %%
stop = ['매일경제','지난해','4','연합뉴스','가운데','한국의','주요','출처','7월','6월','8월','필요','전체']
maekyung_result = del_word(maekyung_result,stop)
# Out:
# ...
# 전체

# %%
maekyung_result.to_excel('2019_maekyung_word.xlsx')

# %%
hankyung_result.head()
# Out:
#        tag  size
# 0  "'조센징'들     1
# 1    "19FW     1
# 2    "2차보복     1
# 3     "3분기     1
# 4  "DHC코리아     2
