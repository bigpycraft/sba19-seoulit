# %%
import pandas as pd

# %%
land = pd.read_excel('./data/토지(매매)_실거래가_20190915.xlsx', encoding='EUC-KR')
land
# Out:
#      □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 0     □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN        NaN
# 1     □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN        NaN
# 2     □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN        NaN
# 3     * 주택매매 거래는 부동산 거래신고 등에 관한 법률 제3조에 따라 계약일로부터 60...        NaN        NaN
# 4     * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 콜센터 1588-01...        NaN        NaN
# 5                                                □ 검색조건        NaN        NaN
# 6                            계약일자 : 20180905 ~ 20190831        NaN        NaN
# 7                                       실거래 구분 : 토지(매매)        NaN        NaN
# 8                                           주소구분 : 지번주소        NaN        NaN
# 9                                            시도 : 울산광역시        NaN        NaN
# 10                                             시군구 : 전체        NaN        NaN
# ...

# %%
len(land)
# Out:
# 6734

# %%
land = land.drop(land.index[0:15])

# %%
land
# Out:
#      □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 15                                                  시군구         번지         지목
# 16                                         울산광역시 남구 두왕동        산8*         임야
# 17                                         울산광역시 남구 두왕동        산8*         임야
# 18                                         울산광역시 남구 두왕동        산8*         임야
# 19                                    울산광역시 울주군 온산읍 덕신리       산3**         임야
# 20                                    울산광역시 울주군 범서읍 두산리        4**          전
# 21                                         울산광역시 북구 진장동         2*          대
# 22                                    울산광역시 울주군 상북면 길천리        8**          대
# 23                                    울산광역시 울주군 두서면 복안리       1***          답
# 24                                    울산광역시 울주군 삼남면 교동리        9**          전
# 25                                    울산광역시 울주군 삼남면 가천리       1***          대
# ...

# %%
land = land.rename(columns={'□ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다.' : '시군구',
                           'Unnamed: 1':'번지',
                           'Unnamed: 2':'지목',
                           'Unnamed: 3':'용도지역',
                           'Unnamed: 4':'도로조건',
                           'Unnamed: 5':'계약년월',
                           'Unnamed: 6':'계약일',
                           'Unnamed: 7':'계약면적(㎡)',
                           'Unnamed: 8':'거래금액(만원)',
                           'Unnamed: 9':'지분구분'})

# %%
land = land.drop(15)
land
# Out:
#                      시군구    번지    지목       용도지역   도로조건    계약년월 계약일  계약면적(㎡)  \
# 16          울산광역시 남구 두왕동   산8*    임야     개발제한구역      -  201809   5       66
# 17          울산광역시 남구 두왕동   산8*    임야     개발제한구역      -  201809   5       66
# 18          울산광역시 남구 두왕동   산8*    임야     개발제한구역      -  201809   5       99
# 19     울산광역시 울주군 온산읍 덕신리  산3**    임야  제1종일반주거지역  12m미만  201809   5    64.14
# 20     울산광역시 울주군 범서읍 두산리   4**     전     자연녹지지역   8m미만  201809   5      806
# 21          울산광역시 북구 진장동    2*     대      준주거지역  12m미만  201809   5    106.5
# 22     울산광역시 울주군 상북면 길천리   8**     대     자연녹지지역   8m미만  201809   5      268
# 23     울산광역시 울주군 두서면 복안리  1***     답       농림지역   8m미만  201809   5   1660.8
# 24     울산광역시 울주군 삼남면 교동리   9**     전  제2종일반주거지역      -  201809   5      242
# 25     울산광역시 울주군 삼남면 가천리  1***     대     자연녹지지역      -  201809   5      269
# 26     울산광역시 울주군 상북면 지내리   5**     답     생산녹지지역   8m미만  201809   5      737
# ...

# %%
len(land)
# Out:
# 6718

# %%
len(land['시군구'][16])
# Out:
# 12

# %%
len(land['시군구'][20])
# Out:
# 17

# %%
list_len = []

# %%
sc = len(land)

# %%
for i in range(sc):
    list_len.append(len(land['시군구'][i+16]))

# %%
list_len
# Out:
# [12,
#  12,
#  12,
#  17,
#  17,
#  12,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  16,
#  17,
#  12,
#  17,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  17,
#  12,
#  17,
#  12,
#  12,
#  16,
#  17,
#  12,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  16,
#  17,
#  17,
#  16,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  18,
#  17,
#  17,
#  17,
#  17,
#  12,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  12,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  12,
#  17,
#  17,
#  17,
#  17,
#  17,
#  12,
#  12,
#  12,
#  17,
#  17,
#  16,
#  17,
#  20,
#  11,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  12,
#  12,
#  12,
#  17,
#  12,
#  17,
#  17,
#  12,
#  12,
#  12,
#  17,
#  17,
#  17,
#  12,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  12,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  12,
#  17,
#  17,
#  17,
#  16,
#  17,
#  16,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  12,
#  12,
#  17,
#  16,
#  17,
#  17,
# ...

# %%
land['a'] = list_len

# %%
land.head(20)
# Out:
#                   시군구    번지   지목       용도지역   도로조건    계약년월 계약일  계약면적(㎡)  \
# 16       울산광역시 남구 두왕동   산8*   임야     개발제한구역      -  201809   5       66
# 17       울산광역시 남구 두왕동   산8*   임야     개발제한구역      -  201809   5       66
# 18       울산광역시 남구 두왕동   산8*   임야     개발제한구역      -  201809   5       99
# 19  울산광역시 울주군 온산읍 덕신리  산3**   임야  제1종일반주거지역  12m미만  201809   5    64.14
# 20  울산광역시 울주군 범서읍 두산리   4**    전     자연녹지지역   8m미만  201809   5      806
# 21       울산광역시 북구 진장동    2*    대      준주거지역  12m미만  201809   5    106.5
# 22  울산광역시 울주군 상북면 길천리   8**    대     자연녹지지역   8m미만  201809   5      268
# 23  울산광역시 울주군 두서면 복안리  1***    답       농림지역   8m미만  201809   5   1660.8
# 24  울산광역시 울주군 삼남면 교동리   9**    전  제2종일반주거지역      -  201809   5      242
# 25  울산광역시 울주군 삼남면 가천리  1***    대     자연녹지지역      -  201809   5      269
# 26  울산광역시 울주군 상북면 지내리   5**    답     생산녹지지역   8m미만  201809   5      737
# 27  울산광역시 울주군 서생면 신암리   2**  잡종지     자연녹지지역   8m미만  201809   5      105
# ...

# %%
land['시군구'][16][0:9]
# Out:
# '울산광역시 남구 '

# %%
for i in range(sc):
    land['시군구'][i+16] = land['시군구'][i+16][0:9]
# Out:
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
land['시군구'].head(20)
# Out:
# 16    울산광역시 남구
# 17    울산광역시 남구
# 18    울산광역시 남구
# 19    울산광역시 울주군
# 20    울산광역시 울주군
# 21    울산광역시 북구
# 22    울산광역시 울주군
# 23    울산광역시 울주군
# 24    울산광역시 울주군
# 25    울산광역시 울주군
# 26    울산광역시 울주군
# 27    울산광역시 울주군
# 28    울산광역시 울주군
# 29    울산광역시 울주군
# 30    울산광역시 울주군
# 31    울산광역시 북구
# 32    울산광역시 울주군
# 33    울산광역시 북구
# 34    울산광역시 중구
# 35    울산광역시 북구
# Name: 시군구, dtype: object

# %%
gun = set(land['시군구'])
gun
# Out:
# {'울산광역시 남구 ', '울산광역시 동구 ', '울산광역시 북구 ', '울산광역시 울주군', '울산광역시 중구 '}

# %%
L = set(land['용도지역'])
L
# Out:
# {'개발제한구역',
#  '계획관리지역',
#  '근린상업지역',
#  '농림지역',
#  '보전관리지역',
#  '보전녹지지역',
#  '생산관리지역',
#  '생산녹지지역',
#  '용도미지정',
#  '유통상업지역',
#  '일반공업지역',
#  '일반상업지역',
#  '일반주거지역',
#  '자연녹지지역',
#  '자연환경보전',
#  '전용공업지역',
#  '제1종일반주거지역',
#  '제1종전용주거지역',
#  '제2종일반주거지역',
#  '제3종일반주거지역',
#  '준공업지역',
#  '준주거지역',
#  '중심상업지역'}

# %%
land = land[land['용도지역'].isin(['제1종일반주거지역', '제1종전용주거지역','제2종일반주거지역', '제3종일반주거지역'])]
land
# Out:
#             시군구    번지    지목       용도지역   도로조건    계약년월 계약일  계약면적(㎡) 거래금액(만원)  \
# 19    울산광역시 울주군  산3**    임야  제1종일반주거지역  12m미만  201809   5    64.14    1,977
# 24    울산광역시 울주군   9**     전  제2종일반주거지역      -  201809   5      242   12,500
# 32    울산광역시 울주군   4**     전  제1종일반주거지역      -  201809   5       52    3,745
# 40    울산광역시 울주군  1***     대  제2종일반주거지역  25m미만  201809   5    396.8   60,000
# 49    울산광역시 울주군   산6*    임야  제1종일반주거지역      -  201809   6       30    1,323
# 51    울산광역시 울주군   산2*    임야  제1종일반주거지역      -  201809   6       33    1,470
# 58    울산광역시 울주군   산2*    임야  제1종일반주거지역      -  201809   6       49    2,205
# 61    울산광역시 울주군   산2*    임야  제1종일반주거지역      -  201809   6       66    2,940
# 62    울산광역시 울주군   산2*    임야  제1종일반주거지역      -  201809   6       66    2,940
# 63    울산광역시 울주군   산2*    임야  제1종일반주거지역      -  201809   6       66    2,940
# 67    울산광역시 울주군   산7*    임야  제1종일반주거지역      -  201809   6    115.5    3,635
# ...

# %%
LL = set(land['지목'])
LL
# Out:
# {'공원',
#  '공장용지',
#  '과수원',
#  '구거',
#  '답',
#  '대',
#  '도로',
#  '묘지',
#  '유지',
#  '임야',
#  '잡종지',
#  '전',
#  '종교용지',
#  '주차장',
#  '창고용지',
#  '하천',
#  '학교용지'}

# %%
type(land['거래금액(만원)'][19])
# Out:
# str

# %%
type(land['계약면적(㎡)'][19])
# Out:
# str

# %%
land['거래금액(만원)'] = land['거래금액(만원)'].str.replace(',','')
# Out:
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
land.head(10)
# Out:
#           시군구    번지  지목       용도지역   도로조건    계약년월 계약일 계약면적(㎡) 거래금액(만원) 지분구분  \
# 19  울산광역시 울주군  산3**  임야  제1종일반주거지역  12m미만  201809   5   64.14     1977   지분
# 24  울산광역시 울주군   9**   전  제2종일반주거지역      -  201809   5     242    12500
# 32  울산광역시 울주군   4**   전  제1종일반주거지역      -  201809   5      52     3745
# 40  울산광역시 울주군  1***   대  제2종일반주거지역  25m미만  201809   5   396.8    60000
# 49  울산광역시 울주군   산6*  임야  제1종일반주거지역      -  201809   6      30     1323   지분
# 51  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6      33     1470   지분
# 58  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6      49     2205   지분
# 61  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6      66     2940   지분
# 62  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6      66     2940   지분
# 63  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6      66     2940   지분
#
#      a
# 19  17
# 24  17
# 32  17
# 40  17
# 49  17
# 51  17
# 58  17
# 61  17
# 62  17
# 63  17

# %%
land['거래금액(만원)'] = pd.to_numeric(land['거래금액(만원)'])
# Out:
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
land.head(10)
# Out:
#           시군구    번지  지목       용도지역   도로조건    계약년월 계약일 계약면적(㎡)  거래금액(만원) 지분구분  \
# 19  울산광역시 울주군  산3**  임야  제1종일반주거지역  12m미만  201809   5   64.14      1977   지분
# 24  울산광역시 울주군   9**   전  제2종일반주거지역      -  201809   5     242     12500
# 32  울산광역시 울주군   4**   전  제1종일반주거지역      -  201809   5      52      3745
# 40  울산광역시 울주군  1***   대  제2종일반주거지역  25m미만  201809   5   396.8     60000
# 49  울산광역시 울주군   산6*  임야  제1종일반주거지역      -  201809   6      30      1323   지분
# 51  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6      33      1470   지분
# 58  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6      49      2205   지분
# 61  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6      66      2940   지분
# 62  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6      66      2940   지분
# 63  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6      66      2940   지분
#
#      a
# 19  17
# 24  17
# 32  17
# 40  17
# 49  17
# 51  17
# 58  17
# 61  17
# 62  17
# 63  17

# %%
type(land['거래금액(만원)'][19])
# Out:
# numpy.int64

# %%
land['계약면적(㎡)'] = pd.to_numeric(land['계약면적(㎡)'])
# Out:
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
land.head(10)
# Out:
#           시군구    번지  지목       용도지역   도로조건    계약년월 계약일  계약면적(㎡)  거래금액(만원) 지분구분  \
# 19  울산광역시 울주군  산3**  임야  제1종일반주거지역  12m미만  201809   5    64.14      1977   지분
# 24  울산광역시 울주군   9**   전  제2종일반주거지역      -  201809   5   242.00     12500
# 32  울산광역시 울주군   4**   전  제1종일반주거지역      -  201809   5    52.00      3745
# 40  울산광역시 울주군  1***   대  제2종일반주거지역  25m미만  201809   5   396.80     60000
# 49  울산광역시 울주군   산6*  임야  제1종일반주거지역      -  201809   6    30.00      1323   지분
# 51  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6    33.00      1470   지분
# 58  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6    49.00      2205   지분
# 61  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6    66.00      2940   지분
# 62  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6    66.00      2940   지분
# 63  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6    66.00      2940   지분
#
#      a
# 19  17
# 24  17
# 32  17
# 40  17
# 49  17
# 51  17
# 58  17
# 61  17
# 62  17
# 63  17

# %%
type(land['계약면적(㎡)'][19])
# Out:
# numpy.float64

# %%
land['실거래가'] = land['계약면적(㎡)'] * land['거래금액(만원)']
# Out:
# C:\Python\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
land['실거래가'].head(10)
# Out:
# 19      126804.78
# 24     3025000.00
# 32      194740.00
# 40    23808000.00
# 49       39690.00
# 51       48510.00
# 58      108045.00
# 61      194040.00
# 62      194040.00
# 63      194040.00
# Name: 실거래가, dtype: float64

# %%
land.head(10)
# Out:
#           시군구    번지  지목       용도지역   도로조건    계약년월 계약일  계약면적(㎡)  거래금액(만원) 지분구분  \
# 19  울산광역시 울주군  산3**  임야  제1종일반주거지역  12m미만  201809   5    64.14      1977   지분
# 24  울산광역시 울주군   9**   전  제2종일반주거지역      -  201809   5   242.00     12500
# 32  울산광역시 울주군   4**   전  제1종일반주거지역      -  201809   5    52.00      3745
# 40  울산광역시 울주군  1***   대  제2종일반주거지역  25m미만  201809   5   396.80     60000
# 49  울산광역시 울주군   산6*  임야  제1종일반주거지역      -  201809   6    30.00      1323   지분
# 51  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6    33.00      1470   지분
# 58  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6    49.00      2205   지분
# 61  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6    66.00      2940   지분
# 62  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6    66.00      2940   지분
# 63  울산광역시 울주군   산2*  임야  제1종일반주거지역      -  201809   6    66.00      2940   지분
#
#      a         실거래가
# 19  17    126804.78
# 24  17   3025000.00
# 32  17    194740.00
# 40  17  23808000.00
# ...

# %%
land
# Out:
#             시군구    번지    지목       용도지역   도로조건    계약년월 계약일  계약면적(㎡)  거래금액(만원)  \
# 19    울산광역시 울주군  산3**    임야  제1종일반주거지역  12m미만  201809   5    64.14      1977
# 24    울산광역시 울주군   9**     전  제2종일반주거지역      -  201809   5   242.00     12500
# 32    울산광역시 울주군   4**     전  제1종일반주거지역      -  201809   5    52.00      3745
# 40    울산광역시 울주군  1***     대  제2종일반주거지역  25m미만  201809   5   396.80     60000
# 49    울산광역시 울주군   산6*    임야  제1종일반주거지역      -  201809   6    30.00      1323
# 51    울산광역시 울주군   산2*    임야  제1종일반주거지역      -  201809   6    33.00      1470
# 58    울산광역시 울주군   산2*    임야  제1종일반주거지역      -  201809   6    49.00      2205
# 61    울산광역시 울주군   산2*    임야  제1종일반주거지역      -  201809   6    66.00      2940
# 62    울산광역시 울주군   산2*    임야  제1종일반주거지역      -  201809   6    66.00      2940
# 63    울산광역시 울주군   산2*    임야  제1종일반주거지역      -  201809   6    66.00      2940
# 67    울산광역시 울주군   산7*    임야  제1종일반주거지역      -  201809   6   115.50      3635
# ...

# %%
len(land)
# Out:
# 1188

# %%
set(land['시군구'])
# Out:
# {'울산광역시 남구 ', '울산광역시 동구 ', '울산광역시 북구 ', '울산광역시 울주군', '울산광역시 중구 '}

# %%
land.to_csv('토지매매가.csv', header=True, index=False, encoding='EUC-KR')
