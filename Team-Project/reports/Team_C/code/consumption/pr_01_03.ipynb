# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc

# font_name = font_manager.FontProperties(fname="/Library/Fonts/AppleGothic.ttf").get_name()
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/MALGUN.TTF").get_name()
rc('font', family=font_name)

plt.rcParams['figure.figsize'] = (12,8)

# %%
df=pd.read_csv('./age_asset1.csv',encoding='euc-kr',header=1)

# %%
pwd()
# Out:
# 'C:\\Users\\PC\\Desktop\\새 폴더\\esu'

# %%
df
# Out:
#   부채보유 여부별 가구주 연령계층별(10세) 자산, 부채, 소득 분류별  전가구 평균 (만원)  전가구 평균 (만원).1  \
# 0       전체         30세 미만       가구분포 (%)          3.7            3.4
# 1       전체         30세 미만      순자산액 (만원)       7671.0         7152.0
# 2       전체         30~39세       가구분포 (%)         18.5           18.5
# 3       전체         30~39세      순자산액 (만원)      18342.0        17745.0
# 4       전체         40~49세       가구분포 (%)         26.2           26.2
# 5       전체         40~49세      순자산액 (만원)      27460.0        25864.0
# 6       전체         50~59세       가구분포 (%)         23.3           24.5
# 7       전체         50~59세      순자산액 (만원)      35116.0        34894.0
# 8       전체          60세이상       가구분포 (%)         28.3           27.3
# 9       전체          60세이상      순자산액 (만원)      27640.0        29140.0
#
#    전가구 평균 (만원).2  전가구 평균 (만원).3  전가구 평균 (만원).4  전가구 평균 (만원).5
# 0            2.5            2.3            2.3            2.5
# 1         7296.0         7373.0         6956.0         7489.0
# ...

# %%
df.groupby(['가구주 연령계층별(10세)','자산, 부채, 소득 분류별']).sum()
# Out:
#                                전가구 평균 (만원)  전가구 평균 (만원).1  전가구 평균 (만원).2  \
# 가구주 연령계층별(10세) 자산, 부채, 소득 분류별
# 30~39세         가구분포 (%)               18.5           18.5           17.8
#                순자산액 (만원)           18342.0        17745.0        17970.0
# 30세 미만         가구분포 (%)                3.7            3.4            2.5
#                순자산액 (만원)            7671.0         7152.0         7296.0
# 40~49세         가구분포 (%)               26.2           26.2           26.4
#                순자산액 (만원)           27460.0        25864.0        26156.0
# 50~59세         가구분포 (%)               23.3           24.5           25.2
#                순자산액 (만원)           35116.0        34894.0        35393.0
# 60세이상          가구분포 (%)               28.3           27.3           28.1
#                순자산액 (만원)           27640.0        29140.0        29463.0
#
#                                전가구 평균 (만원).3  전가구 평균 (만원).4  전가구 평균 (만원).5
# 가구주 연령계층별(10세) 자산, 부채, 소득 분류별
# ...

# %%
df2=pd.read_csv('./age_asset2.csv',encoding='euc-kr',header=1)

# %%
df2
# Out:
#   부채보유 여부별 가구주 연령계층별(10세) 자산, 부채, 소득 분류별  전가구 평균 (만원)  전가구 평균 (만원).1
# 0       전체         30세 미만       가구분포 (%)          2.5            2.2
# 1       전체         30세 미만      순자산액 (만원)       7489.0         7509.0
# 2       전체         30~39세       가구분포 (%)         14.8           13.6
# 3       전체         30~39세      순자산액 (만원)      21904.0        23186.0
# 4       전체         40~49세       가구분포 (%)         24.3           23.6
# 5       전체         40~49세      순자산액 (만원)      31246.0        34426.0
# 6       전체         50~59세       가구분포 (%)         25.4           25.2
# 7       전체         50~59세      순자산액 (만원)      37026.0        39419.0
# 8       전체          60세이상       가구분포 (%)         33.1           35.4
# 9       전체          60세이상      순자산액 (만원)      33772.0        35817.0

# %%
df3=pd.merge(df,df2,on=['가구주 연령계층별(10세)','부채보유 여부별','자산, 부채, 소득 분류별'])

# %%
df3=df3.drop(['부채보유 여부별'],axis=1)

# %%
df3
# Out:
#   가구주 연령계층별(10세) 자산, 부채, 소득 분류별  전가구 평균 (만원)_x  전가구 평균 (만원).1_x  \
# 0         30세 미만       가구분포 (%)            3.7              3.4
# 1         30세 미만      순자산액 (만원)         7671.0           7152.0
# 2         30~39세       가구분포 (%)           18.5             18.5
# 3         30~39세      순자산액 (만원)        18342.0          17745.0
# 4         40~49세       가구분포 (%)           26.2             26.2
# 5         40~49세      순자산액 (만원)        27460.0          25864.0
# 6         50~59세       가구분포 (%)           23.3             24.5
# 7         50~59세      순자산액 (만원)        35116.0          34894.0
# 8          60세이상       가구분포 (%)           28.3             27.3
# 9          60세이상      순자산액 (만원)        27640.0          29140.0
#
#    전가구 평균 (만원).2  전가구 평균 (만원).3  전가구 평균 (만원).4  전가구 평균 (만원).5  전가구 평균 (만원)_y  \
# 0            2.5            2.3            2.3            2.5            2.5
# 1         7296.0         7373.0         6956.0         7489.0         7489.0
# ...

# %%
col_names=['연령대','분류','2012','2013','2014','2015','2016','2017','5555','2018']

# %%
df3.columns=col_names

# %%
df3=df3.drop(['5555'],axis=1)

# %%
df3
# Out:
#       연령대         분류     2012     2013     2014     2015     2016     2017  \
# 0  30세 미만   가구분포 (%)      3.7      3.4      2.5      2.3      2.3      2.5
# 1  30세 미만  순자산액 (만원)   7671.0   7152.0   7296.0   7373.0   6956.0   7489.0
# 2  30~39세   가구분포 (%)     18.5     18.5     17.8     16.6     16.0     14.8
# 3  30~39세  순자산액 (만원)  18342.0  17745.0  17970.0  19207.0  20109.0  21904.0
# 4  40~49세   가구분포 (%)     26.2     26.2     26.4     25.8     25.1     24.3
# 5  40~49세  순자산액 (만원)  27460.0  25864.0  26156.0  26467.0  29125.0  31246.0
# 6  50~59세   가구분포 (%)     23.3     24.5     25.2     25.5     25.3     25.4
# 7  50~59세  순자산액 (만원)  35116.0  34894.0  35393.0  34940.0  36113.0  37026.0
# 8   60세이상   가구분포 (%)     28.3     27.3     28.1     29.7     31.3     33.1
# 9   60세이상  순자산액 (만원)  27640.0  29140.0  29463.0  31346.0  32218.0  33772.0
#
#       2018
# 0      2.2
# 1   7509.0
# 2     13.6
# 3  23186.0
# 4     23.6
# 5  34426.0
# 6     25.2
# 7  39419.0
# 8     35.4
# 9  35817.0

# %%
df_new=df3.set_index(['분류','연령대'])

# %%
df_new
# Out:
#                      2012     2013     2014     2015     2016     2017  \
# 분류        연령대
# 가구분포 (%)  30세 미만      3.7      3.4      2.5      2.3      2.3      2.5
# 순자산액 (만원) 30세 미만   7671.0   7152.0   7296.0   7373.0   6956.0   7489.0
# 가구분포 (%)  30~39세     18.5     18.5     17.8     16.6     16.0     14.8
# 순자산액 (만원) 30~39세  18342.0  17745.0  17970.0  19207.0  20109.0  21904.0
# 가구분포 (%)  40~49세     26.2     26.2     26.4     25.8     25.1     24.3
# 순자산액 (만원) 40~49세  27460.0  25864.0  26156.0  26467.0  29125.0  31246.0
# 가구분포 (%)  50~59세     23.3     24.5     25.2     25.5     25.3     25.4
# 순자산액 (만원) 50~59세  35116.0  34894.0  35393.0  34940.0  36113.0  37026.0
# 가구분포 (%)  60세이상      28.3     27.3     28.1     29.7     31.3     33.1
# 순자산액 (만원) 60세이상   27640.0  29140.0  29463.0  31346.0  32218.0  33772.0
#
#                      2018
# 분류        연령대
# 가구분포 (%)  30세 미만      2.2
# 순자산액 (만원) 30세 미만   7509.0
# 가구분포 (%)  30~39세     13.6
# 순자산액 (만원) 30~39세  23186.0
# ...

# %%
df_new1=df_new.T

# %%
df_new1
# Out:
# 분류   가구분포 (%) 순자산액 (만원) 가구분포 (%) 순자산액 (만원) 가구분포 (%) 순자산액 (만원) 가구분포 (%)  \
# 연령대    30세 미만    30세 미만   30~39세    30~39세   40~49세    40~49세   50~59세
# 2012      3.7    7671.0     18.5   18342.0     26.2   27460.0     23.3
# 2013      3.4    7152.0     18.5   17745.0     26.2   25864.0     24.5
# 2014      2.5    7296.0     17.8   17970.0     26.4   26156.0     25.2
# 2015      2.3    7373.0     16.6   19207.0     25.8   26467.0     25.5
# 2016      2.3    6956.0     16.0   20109.0     25.1   29125.0     25.3
# 2017      2.5    7489.0     14.8   21904.0     24.3   31246.0     25.4
# 2018      2.2    7509.0     13.6   23186.0     23.6   34426.0     25.2
#
# 분류   순자산액 (만원) 가구분포 (%) 순자산액 (만원)
# 연령대     50~59세    60세이상     60세이상
# 2012   35116.0     28.3   27640.0
# 2013   34894.0     27.3   29140.0
# 2014   35393.0     28.1   29463.0
# 2015   34940.0     29.7   31346.0
# 2016   36113.0     31.3   32218.0
# 2017   37026.0     33.1   33772.0
# 2018   39419.0     35.4   35817.0

# %%
df_new2=df_new1['가구분포 (%)']
df_new3=df_new1['순자산액 (만원)']

# %%
df_new3
# Out:
# 연령대   30세 미만   30~39세   40~49세   50~59세    60세이상
# 2012  7671.0  18342.0  27460.0  35116.0  27640.0
# 2013  7152.0  17745.0  25864.0  34894.0  29140.0
# 2014  7296.0  17970.0  26156.0  35393.0  29463.0
# 2015  7373.0  19207.0  26467.0  34940.0  31346.0
# 2016  6956.0  20109.0  29125.0  36113.0  32218.0
# 2017  7489.0  21904.0  31246.0  37026.0  33772.0
# 2018  7509.0  23186.0  34426.0  39419.0  35817.0

# %%
df_new2.to_csv('./pro_01.csv',encoding='euc-kr')
df_new3.to_csv('./pro_02.csv',encoding='euc-kr')

# %%
df_new2
# Out:
# 연령대   30세 미만  30~39세  40~49세  50~59세  60세이상
# 2012     3.7    18.5    26.2    23.3   28.3
# 2013     3.4    18.5    26.2    24.5   27.3
# 2014     2.5    17.8    26.4    25.2   28.1
# 2015     2.3    16.6    25.8    25.5   29.7
# 2016     2.3    16.0    25.1    25.3   31.3
# 2017     2.5    14.8    24.3    25.4   33.1
# 2018     2.2    13.6    23.6    25.2   35.4

# %%
df_new3
# Out:
# 연령대   30세 미만   30~39세   40~49세   50~59세    60세이상
# 2012  7671.0  18342.0  27460.0  35116.0  27640.0
# 2013  7152.0  17745.0  25864.0  34894.0  29140.0
# 2014  7296.0  17970.0  26156.0  35393.0  29463.0
# 2015  7373.0  19207.0  26467.0  34940.0  31346.0
# 2016  6956.0  20109.0  29125.0  36113.0  32218.0
# 2017  7489.0  21904.0  31246.0  37026.0  33772.0
# 2018  7509.0  23186.0  34426.0  39419.0  35817.0

# %%
COLOR = 'red'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

# %%
dfnn1 = df_new2['30세 미만']
dfnn2 = df_new2['30~39세']
dfnn3 = df_new2['40~49세']
dfnn4 = df_new2['50~59세']
dfnn5 = df_new2['60세이상']

# %%
dfn1 = df_new3['30세 미만']
dfn2 = df_new3['30~39세']
dfn3 = df_new3['40~49세']
dfn4 = df_new3['50~59세']
dfn5 = df_new3['60세이상']

# %%
COLOR = 'cyan'
plt.rcParams["figure.figsize"] = [25,14]
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

# %%
t = np.arange(0,7)
plt.figure(figsize=(25,14))
plt.plot(t,dfn1, color='green', linestyle='dashed', marker='o', label='~30')
plt.plot(t,dfn2, color='blue', linestyle='dashed', marker='^', label='30s')
plt.plot(t,dfn3, color='pink', linestyle='dashed', marker='s', label='40s')
plt.plot(t,dfn4, color='cyan', linestyle='dashed', marker='*', label='50s')
plt.plot(t,dfn5, label='60+', lw = 6)
plt.legend(loc = 'lower right')
plt.grid()
plt.xticks(t, ('2012','2013','2014','2015','2016','2017','2018'), fontsize=23)
plt.xlabel('연도별 자산보유현황', fontsize = 25)
#plt.ylabel('Amplitude', fontsize = 30)
plt.show()

# %%
plot1=df_new3.plot(grid=True)
plot1.set_title('연도별 자산보유현황')
plt.xlim
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plot1=df_new3.plot(grid=True)
plot1.set_title('연도별 자산보유현황')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
t = np.arange(0,7)
plt.figure(figsize=(25,14))
plt.plot(t,dfnn1, color='green', linestyle='dashed', marker='o', label='~30')
plt.plot(t,dfnn2, color='blue', linestyle='dashed', marker='^', label='30s')
plt.plot(t,dfnn3, color='pink', linestyle='dashed', marker='s', label='40s')
plt.plot(t,dfnn4, color='cyan', linestyle='dashed', marker='*', label='50s')
plt.plot(t,dfnn5, label='60+', lw = 6)
plt.legend(loc = 'lower right')
plt.grid()
plt.xticks(t, ('2012','2013','2014','2015','2016','2017','2018'), fontsize=23)
plt.xlabel('연도별 인구분포율 변화', fontsize = 25)
#plt.ylabel('Amplitude', fontsize = 30)
plt.show()

# %%
plot2=df_new2.plot(grid=True)
plot2.set_title('연도별 인구분포율 변화')
#plt.xlim(2,50)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
 
# y-axis in bold
rc('font', weight='bold')
 
# Values of each group
bars1 = [12, 28, 1, 8, 22]
bars2 = [28, 7, 16, 4, 10]
bars3 = [25, 3, 23, 25, 17]
 
# Heights of bars1 + bars2
bars = np.add(bars1, bars2).tolist()
 
# The position of the bars on the x-axis
r = [0,1,2,3,4]
 
# Names of group and bar width
names = ['A','B','C','D','E']
barWidth = 1
 
# Create brown bars
plt.bar(r, bars1, color='#7f6d5f', edgecolor='white', width=barWidth)
# Create green bars (middle), on top of the firs ones
plt.bar(r, bars2, bottom=bars1, color='#557f2d', edgecolor='white', width=barWidth)
# Create green bars (top)
plt.bar(r, bars3, bottom=bars, color='#2d7f5e', edgecolor='white', width=barWidth)
 
# Custom X axis
plt.xticks(r, names, fontweight='bold')
plt.xlabel("group")
 
# Show graphic
plt.show()
