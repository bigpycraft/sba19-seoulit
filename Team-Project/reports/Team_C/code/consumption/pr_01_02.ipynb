# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import IPython
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df1=pd.read_csv('./expend1.csv',encoding='euc-kr')
df2=pd.read_csv('./expend2.csv',encoding='euc-kr')

# %%
df2=df2.drop(['2014.1','2015.1','2016.1','2017.1'],axis=1)

# %%
df1=df1.drop(['2017.1','2018 p).1'],axis=1)

# %%
df1.columns=['연령대별', '목적', '2017', '2018']

# %%
df2.columns=['연령대별', '목적', '2014', '2015', '2016', '2017']

# %%
df2.iloc[3,2]
# Out:
# '348'

# %%
# ?DataFrame.groupby
# Out:
# Object `DataFrame.groupby` not found.

# %%
#for i in range(6):
#    for j in range(2,8):
#        print(df2.iloc[i+j,2])

# %%
df3=df2.set_index('연령대별')[2:8]
df4=df2.set_index('연령대별')[10:16]
df5=df2.set_index('연령대별')[18:24]
df6=df2.set_index('연령대별')[26:32]
df7=df2.set_index('연령대별')[34:40]
df8=df2.set_index('연령대별')[42:48]

# %%
df3_new=df3.set_index('목적')
df4_new=df4.set_index('목적')
df5_new=df5.set_index('목적')
df6_new=df6.set_index('목적')
df7_new=df7.set_index('목적')
df8_new=df8.set_index('목적')

# %%
df3_new['2014']=pd.to_numeric(df3_new['2014'])
df3_new['2015']=pd.to_numeric(df3_new['2015'])
df3_new['2016']=pd.to_numeric(df3_new['2016'])
df3_new['2017']=pd.to_numeric(df3_new['2017'])

df4_new['2014']=pd.to_numeric(df4_new['2014'])
df4_new['2015']=pd.to_numeric(df4_new['2015'])
df4_new['2016']=pd.to_numeric(df4_new['2016'])
df4_new['2017']=pd.to_numeric(df4_new['2017'])

df5_new['2014']=pd.to_numeric(df5_new['2014'])
df5_new['2015']=pd.to_numeric(df5_new['2015'])
df5_new['2016']=pd.to_numeric(df5_new['2016'])
df5_new['2017']=pd.to_numeric(df5_new['2017'])

df6_new['2014']=pd.to_numeric(df6_new['2014'])
df6_new['2015']=pd.to_numeric(df6_new['2015'])
df6_new['2016']=pd.to_numeric(df6_new['2016'])
df6_new['2017']=pd.to_numeric(df6_new['2017'])

df7_new['2014']=pd.to_numeric(df7_new['2014'])
df7_new['2015']=pd.to_numeric(df7_new['2015'])
df7_new['2016']=pd.to_numeric(df7_new['2016'])
df7_new['2017']=pd.to_numeric(df7_new['2017'])

df8_new['2014']=pd.to_numeric(df8_new['2014'])
df8_new['2015']=pd.to_numeric(df8_new['2015'])
df8_new['2016']=pd.to_numeric(df8_new['2016'])
df8_new['2017']=pd.to_numeric(df8_new['2017'])

# %%
df3_pro=df3_new.div(df3_new.sum(axis=0), axis=1)
df4_pro=df4_new.div(df4_new.sum(axis=0), axis=1)
df5_pro=df5_new.div(df5_new.sum(axis=0), axis=1)
df6_pro=df6_new.div(df6_new.sum(axis=0), axis=1)
df7_pro=df7_new.div(df7_new.sum(axis=0), axis=1)
df8_pro=df8_new.div(df8_new.sum(axis=0), axis=1)

# %%
df3_pro
# Out:
#          2014      2015      2016      2017
# 목적
# 식료품  0.359882  0.393443  0.377076  0.385691
# 주거비  0.256637  0.245902  0.252492  0.245888
# 교육비  0.058997  0.052303  0.060631  0.055099
# 의료비  0.056047  0.049180  0.061462  0.061678
# 교통비  0.141593  0.132709  0.123754  0.129112
# 통신비  0.126844  0.126464  0.124585  0.122533

# %%
plt.rcParams['figure.figsize'] = (25,14)
bar_plot3 = df3_pro.T.plot.bar(stacked=True);

# %%
bar_plot7 = df7_pro.T.plot.bar(stacked=True);

# %%
COLOR = 'cyan'
plt.rcParams["figure.figsize"] = [25,14]
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

# %%
bar_plot8 = df8_pro.plot.bar();

# %%
plt.figure(figsize=(12,6))

# %%
plt.rcParams['font.family']        = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df7_new
# Out:
#      2014  2015  2016  2017
# 목적
# 식료품   439   467   476   516
# 주거비   227   232   235   242
# 교육비    46    49    43    41
# 의료비   169   171   183   191
# 교통비   149   154   154   161
# 통신비    86    95    95    98

# %%
df_gr=df2[df2['목적']=='소비지출']
df_gr
# Out:
#                연령대별    목적  2014  2015  2016  2017
# 1   (가구주 연령) 30세 미만  소비지출  1730  1675  1554  1621
# 9   (가구주 연령) 30-39세  소비지출  2354  2387  2424  2542
# 17  (가구주 연령) 40-49세  소비지출  2903  2921  2989  3252
# 25  (가구주 연령) 50-59세  소비지출  2707  2765  2770  2936
# 33  (가구주 연령) 60세 이상  소비지출  1410  1469  1503  1596
# 41      (가구유형) 노인가구  소비지출   893   934   949  1011

# %%
df_gr_old=df_gr[df_gr['연령대별']=='(가구주 연령) 60세 이상']
df_gr_young=df_gr[0:4]

# %%
df_gr_young
# Out:
#                연령대별    목적  2014  2015  2016  2017
# 1   (가구주 연령) 30세 미만  소비지출  1730  1675  1554  1621
# 9   (가구주 연령) 30-39세  소비지출  2354  2387  2424  2542
# 17  (가구주 연령) 40-49세  소비지출  2903  2921  2989  3252
# 25  (가구주 연령) 50-59세  소비지출  2707  2765  2770  2936

# %%
df_gr_young['2014']=pd.to_numeric(df_gr_young['2014'])
df_gr_young['2015']=pd.to_numeric(df_gr_young['2015'])
df_gr_young['2016']=pd.to_numeric(df_gr_young['2016'])
df_gr_young['2017']=pd.to_numeric(df_gr_young['2017'])
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_gr_young_expend=df_gr_young.set_index('연령대별').groupby('목적').sum().T

# %%
df_gr_old_expend=df_gr_old.set_index('연령대별').groupby('목적').sum().T

# %%
df_gr_young_expend.index.name = 'year'
df_gr_old_expend.index.name = 'year'

# %%
df_gr_old_expend
# Out:
# 목적    소비지출
# year
# 2014  1410
# 2015  1469
# 2016  1503
# 2017  1596

# %%
pd.to_datetime(df_gr_old_expend.index)
pd.to_datetime(df_gr_young_expend.index)
# Out:
# DatetimeIndex(['2014-01-01', '2015-01-01', '2016-01-01', '2017-01-01'], dtype='datetime64[ns]', name='year', freq=None)

# %%
df_gr_old_expend
# Out:
# 목적    소비지출
# year
# 2014  1410
# 2015  1469
# 2016  1503
# 2017  1596
