# %%
import platform

import numpy as np
import pandas as pd

from konlpy.corpus import kobill
from konlpy.tag    import Twitter
from wordcloud     import WordCloud, STOPWORDS
from PIL import Image
from collections import Counter 

import nltk
import sys

files_ko = kobill.fileids()
with open("C://Users//OWNER//Anaconda_scr//twitter_data_2016-01-01_to_2018-12-30.csv") as my_file:
    text = my_file.read()
    text
    
    
#불용어처리 nltk
twitter = Twitter()

import nltk
nltk.download('punkt')

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

#stop_words = 불필요한 단어 나열 (주의 간격 spacebar)
stop_words = "퇴 일본 중국 이 등 것 생각 나선 후 때 그 사람 더 내 산 중 말 나 앞 놈 좀 뭐 일 불매운동 날 및 애플 분 봉 회 볼 하리 익금 위 로 거 팬 지금 진짜 이번 안 왜 때문 애 대해 미국 다음 요 저 모 함 레이 수 계속 라모 니 모든 사실"

#twitter.nouns(해당 text 넣기)
stop_words=stop_words.split(' ')
word_tokens = twitter.nouns(text)

#불용어를 제외한 명사만 모두 result에 추출
result = [] 
for w in word_tokens: 
    if w not in stop_words: 
        result.append(w) 

print(word_tokens) 
print(result)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\OWNER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0eefa249b0c0> in <module>
# ----> 1 table(result)
#
# NameError: name 'table' is not defined

# %%
#빈도수 계산하기 Counter
count=Counter(result)
count
# Out:
# Counter({'트위터': 5,
#          '감자탕': 2,
#          '이바돔': 1,
#          '은': 5,
#          '간다': 4,
#          '한국': 83,
#          '음식': 2,
#          '광고': 9,
#          '게이샤': 1,
#          '새끼': 8,
#          '어이': 2,
#          '세계': 10,
#          '보호': 3,
#          '놧더': 3,
#          '싹': 4,
#          '일본여행': 6,
#          '방사': 7,
#          '능': 6,
#          '고래고기': 3,
#          '가나': 3,
#          '상품': 13,
#          '이건': 4,
#          '디': 2,
#          '플레디스': 1,
#          '한성수': 1,
#          '꼭': 2,
#          '시즌': 1,
#          '그리팅': 1,
#          '시위': 1,
#          '스케쥴': 1,
#          '일정': 1,
#          '명': 2,
#          '번역기': 1,
#          '뭘': 2,
#          '하든': 2,
#          '해외': 8,
#          '짓': 10,
#          '하나': 9,
#          '교포': 2,
#          '택시': 2,
#          '회사': 22,
#          '자국': 7,
#          '서비스': 2,
#          '정말': 8,
#          '애용': 1,
#          '얘기': 4,
#          '탈수': 1,
#          '개선': 1,
#          '누가': 3,
# ...

# %%
count2016_2018 = count.most_common(50)
count2016_2018
# Out:
# [('스타벅스', 88),
#  ('한국', 83),
#  ('기업', 69),
#  ('망언', 58),
#  ('해설', 56),
#  ('앨범', 46),
#  ('불매', 42),
#  ('우리', 32),
#  ('제품', 31),
#  ('사과', 31),
#  ('우익', 28),
#  ('국민', 27),
#  ('뉴스', 26),
#  ('전범', 26),
#  ('지배', 26),
#  ('아미', 25),
#  ('조슈아', 24),
#  ('식민지', 24),
#  ('폭풍', 24),
#  ('신상털기', 24),
#  ('쿠퍼', 23),
#  ('회사', 22),
#  ('돈', 22),
#  ('식민', 22),
#  ('이사', 22),
#  ('빅히트', 21),
#  ('한국인', 21),
#  ('우리나라', 20),
#  ('대한', 17),
#  ('피드백', 17),
#  ('대한민국', 17),
#  ('문제', 15),
#  ('나라', 15),
#  ('시작', 15),
#  ('친일', 14),
#  ('방탄', 14),
#  ('극우', 14),
#  ('상품', 13),
#  ('활동', 13),
#  ('방송', 13),
#  ('롯데', 13),
#  ('협업', 13),
#  ('피해', 12),
#  ('국내', 12),
#  ('정부', 12),
#  ('스밍', 12),
#  ('조선', 12),
#  ('발언', 11),
#  ('행동', 11),
#  ('아베', 11)]

# %%
dict(count2016_2018)
# Out:
# {'스타벅스': 88,
#  '한국': 83,
#  '기업': 69,
#  '망언': 58,
#  '해설': 56,
#  '앨범': 46,
#  '불매': 42,
#  '우리': 32,
#  '제품': 31,
#  '사과': 31,
#  '우익': 28,
#  '국민': 27,
#  '뉴스': 26,
#  '전범': 26,
#  '지배': 26,
#  '아미': 25,
#  '조슈아': 24,
#  '식민지': 24,
#  '폭풍': 24,
#  '신상털기': 24,
#  '쿠퍼': 23,
#  '회사': 22,
#  '돈': 22,
#  '식민': 22,
#  '이사': 22,
#  '빅히트': 21,
#  '한국인': 21,
#  '우리나라': 20,
#  '대한': 17,
#  '피드백': 17,
#  '대한민국': 17,
#  '문제': 15,
#  '나라': 15,
#  '시작': 15,
#  '친일': 14,
#  '방탄': 14,
#  '극우': 14,
#  '상품': 13,
#  '활동': 13,
#  '방송': 13,
#  '롯데': 13,
#  '협업': 13,
#  '피해': 12,
#  '국내': 12,
#  '정부': 12,
#  '스밍': 12,
#  '조선': 12,
#  '발언': 11,
#  '행동': 11,
#  '아베': 11}
