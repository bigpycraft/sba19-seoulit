# %%
import platform

import numpy as np
import pandas as pd

from konlpy.corpus import kobill
from konlpy.tag    import Twitter
from wordcloud     import WordCloud, STOPWORDS
from PIL import Image
from collections import Counter 

import nltk
import sys

files_ko = kobill.fileids()
with open("C://Users//OWNER//Anaconda_scr//twitter_data_2013-01-01_to_2013-12-29.csv") as my_file:
    text = my_file.read()
    text
    
    
#불용어처리 nltk
twitter = Twitter()

import nltk
nltk.download('punkt')

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

#stop_words = 불필요한 단어 나열 (주의 간격 spacebar)
stop_words = "일본 중국 이 등 것 생각 나선 후 때 그 사람 더 내 산 중 말 나 앞 놈 좀 뭐 일 불매운동 날 및 애플 분 봉 회 볼 하리 익금 위 로 거 팬 지금 진짜 이번 안 왜 때문 애 대해 미국"

#twitter.nouns(해당 text 넣기)
stop_words=stop_words.split(' ')
word_tokens = twitter.nouns(text)

#불용어를 제외한 명사만 모두 result에 추출
result = [] 
for w in word_tokens: 
    if w not in stop_words: 
        result.append(w) 

print(word_tokens) 
print(result)
# Out:
# C:\Users\OWNER\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\OWNER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
#빈도수 계산하기 Counter
count=Counter(result)
count
# Out:
# Counter({'트위터': 6,
#          '신뢰': 8,
#          '수': 34,
#          '일본차': 4,
#          '추방': 1,
#          '제품': 1243,
#          '독도': 508,
#          '우리땅': 78,
#          '교학사': 88,
#          '교과서': 93,
#          '유권': 100,
#          '주장': 107,
#          '일본인': 88,
#          '논문': 71,
#          '지도': 72,
#          '실어': 71,
#          '전면': 74,
#          '수정': 73,
#          '폐기': 71,
#          '학부모': 71,
#          '국민': 293,
#          '반일감정': 3,
#          '격화': 1,
#          '차': 11,
#          '간문제': 2,
#          '지난': 6,
#          '아베': 39,
#          '신조': 4,
#          '총리': 11,
#          '야스쿠니': 23,
#          '신사': 20,
#          '참배': 6,
#          '중국인': 6,
#          '반일': 27,
#          '감정': 34,
#          '격': 3,
#          '블룸버그': 1,
#          '통신': 1,
#          '보도': 4,
#          '폭풍': 1,
#          '고조': 21,
#          '대규모': 10,
#          '시위': 11,
#          '촉구': 10,
#          '어벙': 1,
#          '연합': 11,
#          '웬': 1,
# ...

# %%
count2013 = count.most_common(50)
count2013
# Out:
# [('제품', 1243),
#  ('업자', 641),
#  ('자영', 639),
#  ('독도', 508),
#  ('전국', 400),
#  ('국민', 293),
#  ('기업', 242),
#  ('동참', 215),
#  ('다케시마', 194),
#  ('한국', 164),
#  ('땅', 153),
#  ('상품', 146),
#  ('우리', 146),
#  ('불매', 145),
#  ('시작', 132),
#  ('캠페인', 120),
#  ('유니클로', 114),
#  ('결의', 110),
#  ('골목', 110),
#  ('아사히맥주', 108),
#  ('주장', 107),
#  ('상권', 101),
#  ('유권', 100),
#  ('소비자', 100),
#  ('교과서', 93),
#  ('소니', 91),
#  ('운동', 89),
#  ('교학사', 88),
#  ('일본인', 88),
#  ('김장훈', 88),
#  ('니콘', 87),
#  ('절', 87),
#  ('뉴스', 84),
#  ('연맹', 84),
#  ('혼다', 82),
#  ('토요타', 81),
#  ('맥주', 79),
#  ('우리땅', 78),
#  ('행사', 78),
#  ('렉서스', 77),
#  ('전면', 74),
#  ('우익', 74),
#  ('마일드세븐', 74),
#  ('수정', 73),
#  ('지도', 72),
#  ('논문', 71),
#  ('실어', 71),
#  ('폐기', 71),
#  ('학부모', 71),
#  ('후원', 71)]

# %%
dict(count2013)
# Out:
# {'제품': 1243,
#  '업자': 641,
#  '자영': 639,
#  '독도': 508,
#  '전국': 400,
#  '국민': 293,
#  '기업': 242,
#  '동참': 215,
#  '다케시마': 194,
#  '한국': 164,
#  '땅': 153,
#  '상품': 146,
#  '우리': 146,
#  '불매': 145,
#  '시작': 132,
#  '캠페인': 120,
#  '유니클로': 114,
#  '결의': 110,
#  '골목': 110,
#  '아사히맥주': 108,
#  '주장': 107,
#  '상권': 101,
#  '유권': 100,
#  '소비자': 100,
#  '교과서': 93,
#  '소니': 91,
#  '운동': 89,
#  '교학사': 88,
#  '일본인': 88,
#  '김장훈': 88,
#  '니콘': 87,
#  '절': 87,
#  '뉴스': 84,
#  '연맹': 84,
#  '혼다': 82,
#  '토요타': 81,
#  '맥주': 79,
#  '우리땅': 78,
#  '행사': 78,
#  '렉서스': 77,
#  '전면': 74,
#  '우익': 74,
#  '마일드세븐': 74,
#  '수정': 73,
#  '지도': 72,
#  '논문': 71,
#  '실어': 71,
#  '폐기': 71,
#  '학부모': 71,
#  '후원': 71}

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path='C:\\Windows\\fonts\\NanumGothic.ttf',
    width=800,
    height=800,
    background_color='white'
)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
wordcloud = wordcloud.generate_from_frequencies(Counter(result))

fig = plt.figure(figsize=(10, 10))
plt.imshow(wordcloud.to_array(), interpolation="bilinear")
plt.show()

# %%
fig.savefig('wordcloud_japan_2013.png')
