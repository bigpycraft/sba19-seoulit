# %%
import platform

import numpy as np
import pandas as pd

from konlpy.corpus import kobill
from konlpy.tag    import Twitter
from wordcloud     import WordCloud, STOPWORDS
from PIL import Image
from collections import Counter 

import nltk
import sys

files_ko = kobill.fileids()
with open("C://Users//OWNER//Anaconda_scr//twitter_data_2015-01-01_to_2015-12-30.csv") as my_file:
    text = my_file.read()
    text
    
    
#불용어처리 nltk
twitter = Twitter()

import nltk
nltk.download('punkt')

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

#stop_words = 불필요한 단어 나열 (주의 간격 spacebar)
stop_words = "불매 이유 일본 이제 를 중국 이 등 것 생각 나선 후 때 그 사람 더 내 산 중 말 나 앞 놈 좀 뭐 일 불매운동 날 및 애플 분 봉 회 볼 하리 익금 위 로 거 팬 지금 진짜 이번 안 왜 때문 애 대해 미국 의 이름 계"

#twitter.nouns(해당 text 넣기)
stop_words=stop_words.split(' ')
word_tokens = twitter.nouns(text)

#불용어를 제외한 명사만 모두 result에 추출
result = [] 
for w in word_tokens: 
    if w not in stop_words: 
        result.append(w) 

print(word_tokens) 
print(result)
# Out:
# C:\Users\OWNER\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# C:\Users\OWNER\Anaconda3\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\OWNER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
#빈도수 계산하기 Counter
count=Counter(result)
count
# Out:
# Counter({'트위터': 3,
#          '우리': 21,
#          '제품': 62,
#          '정부': 14,
#          '무능': 1,
#          '이상': 10,
#          '보고': 1,
#          '선': 13,
#          '협상': 1,
#          '게': 4,
#          '행위': 9,
#          '국민': 51,
#          '여행': 1,
#          '운동': 14,
#          '몽고': 1,
#          '간장': 1,
#          '하나': 2,
#          '선례': 1,
#          '우유': 1,
#          '회사': 14,
#          '문': 1,
#          '기업': 365,
#          '롯데': 876,
#          '거의': 12,
#          '대한민국': 78,
#          '소비': 41,
#          '살': 9,
#          '찌게': 9,
#          '동해': 15,
#          '일본해': 15,
#          '표기': 11,
#          '이케아': 6,
#          '최후': 5,
#          '함': 10,
#          '구매': 5,
#          '맙시': 6,
#          '오픈': 5,
#          '전세계': 10,
#          '상대로': 5,
#          '로비활동': 5,
#          '우익': 8,
#          '발끈': 12,
#          '지원': 4,
#          '하자': 4,
#          '친일': 20,
#          '발언': 11,
#          '여자': 2,
#          '가방': 1,
# ...

# %%
count2015 = count.most_common(50)
count2015
# Out:
# [('롯데', 876),
#  ('기업', 365),
#  ('한국', 79),
#  ('대한민국', 78),
#  ('상공', 77),
#  ('연합', 77),
#  ('면세점', 70),
#  ('기업인', 69),
#  ('제품', 62),
#  ('처음처럼', 62),
#  ('국민', 51),
#  ('사업', 49),
#  ('그룹', 48),
#  ('소비', 41),
#  ('확산', 39),
#  ('돈', 34),
#  ('특혜', 31),
#  ('카드', 30),
#  ('월드', 29),
#  ('시작', 27),
#  ('백화점', 26),
#  ('전개', 25),
#  ('미쓰비시', 25),
#  ('호텔', 23),
#  ('전범', 22),
#  ('제과', 22),
#  ('우리', 21),
#  ('롯데리아', 21),
#  ('경영', 21),
#  ('친일', 20),
#  ('실상', 20),
#  ('마트', 19),
#  ('자이언츠', 19),
#  ('세븐일레븐', 19),
#  ('국정감사', 19),
#  ('분쟁', 19),
#  ('소비자', 18),
#  ('신동빈', 17),
#  ('친일파', 16),
#  ('상권', 16),
#  ('동해', 15),
#  ('일본해', 15),
#  ('한국인', 15),
#  ('경제', 15),
#  ('요구', 15),
#  ('안전', 15),
#  ('열사', 15),
#  ('대상', 15),
#  ('정부', 14),
#  ('운동', 14)]

# %%
dict(count2015)
# Out:
# {'롯데': 876,
#  '기업': 365,
#  '한국': 79,
#  '대한민국': 78,
#  '상공': 77,
#  '연합': 77,
#  '면세점': 70,
#  '기업인': 69,
#  '제품': 62,
#  '처음처럼': 62,
#  '국민': 51,
#  '사업': 49,
#  '그룹': 48,
#  '소비': 41,
#  '확산': 39,
#  '돈': 34,
#  '특혜': 31,
#  '카드': 30,
#  '월드': 29,
#  '시작': 27,
#  '백화점': 26,
#  '전개': 25,
#  '미쓰비시': 25,
#  '호텔': 23,
#  '전범': 22,
#  '제과': 22,
#  '우리': 21,
#  '롯데리아': 21,
#  '경영': 21,
#  '친일': 20,
#  '실상': 20,
#  '마트': 19,
#  '자이언츠': 19,
#  '세븐일레븐': 19,
#  '국정감사': 19,
#  '분쟁': 19,
#  '소비자': 18,
#  '신동빈': 17,
#  '친일파': 16,
#  '상권': 16,
#  '동해': 15,
#  '일본해': 15,
#  '한국인': 15,
#  '경제': 15,
#  '요구': 15,
#  '안전': 15,
#  '열사': 15,
#  '대상': 15,
#  '정부': 14,
#  '운동': 14}

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path='C:\\Windows\\fonts\\NanumGothic.ttf',
    width=800,
    height=800,
    background_color='white'
)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
wordcloud = wordcloud.generate_from_frequencies(Counter(result))

fig = plt.figure(figsize=(10, 10))
plt.imshow(wordcloud.to_array(), interpolation="bilinear")
plt.show()

# %%
fig.savefig('wordcloud_japan_2015.png')
