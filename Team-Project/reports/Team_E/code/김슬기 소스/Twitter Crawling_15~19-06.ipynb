# %%
import tweepy

# %%
consumer_key = "udVuHVp1XIcgKqh2Ewx5rjmfN"
consumer_secret = "0OcxZlWhAPUzBqrkKjCNQxCZ51xFJJegQYQ7mOMbvYfkLWNF5V"

# %%
access_token = "1144837326993932288-5iRQvdI4y7p05l3OP6bGaA8l4R6POi"
access_token_secret= "nAJlPptsR2xfkeiU0ecadb0AY3lwgj0FlUYBanLLPz3xx"

# %%
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print("It's unknown system. Hangul fonts are not supported!")
    
# plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["figure.figsize"] = [12,6]

# %matplotlib inline

# %%
# GetOldTweet3 사용 준비
try:
    import GetOldTweets3 as got
except:
    # !pip install GetOldTweets3
    import GetOldTweets3 as got

# %%
# BeautifulSoup4 사용 준비
try:
    from bs4 import BeautifulSoup
except:
    # !pip install bs4
    from bs4 import BeautifulSoup

# %% [markdown]
# ### 수집 기간 정의

# %%
import datetime

# %%
days_range = []

start = datetime.datetime.strptime("2019-07-01", "%Y-%m-%d")
end = datetime.datetime.strptime("2019-09-10", "%Y-%m-%d") 
date_generated = [start + datetime.timedelta(days=x) for x in range(0, (end-start).days)]

# %%
days_range1 = []

start1 = datetime.datetime.strptime("2015-01-01", "%Y-%m-%d")
end1 = datetime.datetime.strptime("2015-12-31", "%Y-%m-%d") 
date_generated1 = [start1 + datetime.timedelta(days=x) for x in range(0, (end1-start1).days)]

# %%
days_range2 = []

start2 = datetime.datetime.strptime("2016-01-01", "%Y-%m-%d")
end2 = datetime.datetime.strptime("2016-12-31", "%Y-%m-%d") 
date_generated2 = [start2 + datetime.timedelta(days=x) for x in range(0, (end2-start2).days)]

# %%
days_range3 = []

start3 = datetime.datetime.strptime("2017-01-01", "%Y-%m-%d")
end3 = datetime.datetime.strptime("2017-12-31", "%Y-%m-%d") 
date_generated3 = [start3 + datetime.timedelta(days=x) for x in range(0, (end3-start3).days)]

# %%
days_range4 = []

start4 = datetime.datetime.strptime("2018-01-01", "%Y-%m-%d")
end4 = datetime.datetime.strptime("2018-12-31", "%Y-%m-%d") 
date_generated4 = [start4 + datetime.timedelta(days=x) for x in range(0, (end4-start4).days)]

# %%
days_range5 = []

start5 = datetime.datetime.strptime("2019-01-01", "%Y-%m-%d")
end5 = datetime.datetime.strptime("2019-06-30", "%Y-%m-%d") 
date_generated5 = [start5 + datetime.timedelta(days=x) for x in range(0, (end5-start5).days)]

# %%
for date in date_generated:
    days_range.append(date.strftime("%Y-%m-%d"))
    
days_range
# Out:
# ['2019-07-01',
#  '2019-07-02',
#  '2019-07-03',
#  '2019-07-04',
#  '2019-07-05',
#  '2019-07-06',
#  '2019-07-07',
#  '2019-07-08',
#  '2019-07-09',
#  '2019-07-10',
#  '2019-07-11',
#  '2019-07-12',
#  '2019-07-13',
#  '2019-07-14',
#  '2019-07-15',
#  '2019-07-16',
#  '2019-07-17',
#  '2019-07-18',
#  '2019-07-19',
#  '2019-07-20',
#  '2019-07-21',
#  '2019-07-22',
#  '2019-07-23',
#  '2019-07-24',
#  '2019-07-25',
#  '2019-07-26',
#  '2019-07-27',
#  '2019-07-28',
#  '2019-07-29',
#  '2019-07-30',
#  '2019-07-31',
#  '2019-08-01',
#  '2019-08-02',
#  '2019-08-03',
#  '2019-08-04',
#  '2019-08-05',
#  '2019-08-06',
#  '2019-08-07',
#  '2019-08-08',
#  '2019-08-09',
#  '2019-08-10',
#  '2019-08-11',
#  '2019-08-12',
#  '2019-08-13',
#  '2019-08-14',
#  '2019-08-15',
#  '2019-08-16',
#  '2019-08-17',
#  '2019-08-18',
#  '2019-08-19',
#  '2019-08-20',
#  '2019-08-21',
#  '2019-08-22',
#  '2019-08-23',
#  '2019-08-24',
#  '2019-08-25',
#  '2019-08-26',
#  '2019-08-27',
# ...

# %%
for date in date_generated1:
    days_range1.append(date.strftime("%Y-%m-%d"))
    
days_range1
# Out:
# ['2015-01-01',
#  '2015-01-02',
#  '2015-01-03',
#  '2015-01-04',
#  '2015-01-05',
#  '2015-01-06',
#  '2015-01-07',
#  '2015-01-08',
#  '2015-01-09',
#  '2015-01-10',
#  '2015-01-11',
#  '2015-01-12',
#  '2015-01-13',
#  '2015-01-14',
#  '2015-01-15',
#  '2015-01-16',
#  '2015-01-17',
#  '2015-01-18',
#  '2015-01-19',
#  '2015-01-20',
#  '2015-01-21',
#  '2015-01-22',
#  '2015-01-23',
#  '2015-01-24',
#  '2015-01-25',
#  '2015-01-26',
#  '2015-01-27',
#  '2015-01-28',
#  '2015-01-29',
#  '2015-01-30',
#  '2015-01-31',
#  '2015-02-01',
#  '2015-02-02',
#  '2015-02-03',
#  '2015-02-04',
#  '2015-02-05',
#  '2015-02-06',
#  '2015-02-07',
#  '2015-02-08',
#  '2015-02-09',
#  '2015-02-10',
#  '2015-02-11',
#  '2015-02-12',
#  '2015-02-13',
#  '2015-02-14',
#  '2015-02-15',
#  '2015-02-16',
#  '2015-02-17',
#  '2015-02-18',
#  '2015-02-19',
#  '2015-02-20',
#  '2015-02-21',
#  '2015-02-22',
#  '2015-02-23',
#  '2015-02-24',
#  '2015-02-25',
#  '2015-02-26',
#  '2015-02-27',
# ...

# %%
for date in date_generated2:
    days_range2.append(date.strftime("%Y-%m-%d"))
    
days_range2
# Out:
# ['2016-01-01',
#  '2016-01-02',
#  '2016-01-03',
#  '2016-01-04',
#  '2016-01-05',
#  '2016-01-06',
#  '2016-01-07',
#  '2016-01-08',
#  '2016-01-09',
#  '2016-01-10',
#  '2016-01-11',
#  '2016-01-12',
#  '2016-01-13',
#  '2016-01-14',
#  '2016-01-15',
#  '2016-01-16',
#  '2016-01-17',
#  '2016-01-18',
#  '2016-01-19',
#  '2016-01-20',
#  '2016-01-21',
#  '2016-01-22',
#  '2016-01-23',
#  '2016-01-24',
#  '2016-01-25',
#  '2016-01-26',
#  '2016-01-27',
#  '2016-01-28',
#  '2016-01-29',
#  '2016-01-30',
#  '2016-01-31',
#  '2016-02-01',
#  '2016-02-02',
#  '2016-02-03',
#  '2016-02-04',
#  '2016-02-05',
#  '2016-02-06',
#  '2016-02-07',
#  '2016-02-08',
#  '2016-02-09',
#  '2016-02-10',
#  '2016-02-11',
#  '2016-02-12',
#  '2016-02-13',
#  '2016-02-14',
#  '2016-02-15',
#  '2016-02-16',
#  '2016-02-17',
#  '2016-02-18',
#  '2016-02-19',
#  '2016-02-20',
#  '2016-02-21',
#  '2016-02-22',
#  '2016-02-23',
#  '2016-02-24',
#  '2016-02-25',
#  '2016-02-26',
#  '2016-02-27',
# ...

# %%
for date in date_generated3:
    days_range3.append(date.strftime("%Y-%m-%d"))
    
days_range3
# Out:
# ['2017-01-01',
#  '2017-01-02',
#  '2017-01-03',
#  '2017-01-04',
#  '2017-01-05',
#  '2017-01-06',
#  '2017-01-07',
#  '2017-01-08',
#  '2017-01-09',
#  '2017-01-10',
#  '2017-01-11',
#  '2017-01-12',
#  '2017-01-13',
#  '2017-01-14',
#  '2017-01-15',
#  '2017-01-16',
#  '2017-01-17',
#  '2017-01-18',
#  '2017-01-19',
#  '2017-01-20',
#  '2017-01-21',
#  '2017-01-22',
#  '2017-01-23',
#  '2017-01-24',
#  '2017-01-25',
#  '2017-01-26',
#  '2017-01-27',
#  '2017-01-28',
#  '2017-01-29',
#  '2017-01-30',
#  '2017-01-31',
#  '2017-02-01',
#  '2017-02-02',
#  '2017-02-03',
#  '2017-02-04',
#  '2017-02-05',
#  '2017-02-06',
#  '2017-02-07',
#  '2017-02-08',
#  '2017-02-09',
#  '2017-02-10',
#  '2017-02-11',
#  '2017-02-12',
#  '2017-02-13',
#  '2017-02-14',
#  '2017-02-15',
#  '2017-02-16',
#  '2017-02-17',
#  '2017-02-18',
#  '2017-02-19',
#  '2017-02-20',
#  '2017-02-21',
#  '2017-02-22',
#  '2017-02-23',
#  '2017-02-24',
#  '2017-02-25',
#  '2017-02-26',
#  '2017-02-27',
# ...

# %%
for date in date_generated4:
    days_range4.append(date.strftime("%Y-%m-%d"))
    
days_range4
# Out:
# ['2018-01-01',
#  '2018-01-02',
#  '2018-01-03',
#  '2018-01-04',
#  '2018-01-05',
#  '2018-01-06',
#  '2018-01-07',
#  '2018-01-08',
#  '2018-01-09',
#  '2018-01-10',
#  '2018-01-11',
#  '2018-01-12',
#  '2018-01-13',
#  '2018-01-14',
#  '2018-01-15',
#  '2018-01-16',
#  '2018-01-17',
#  '2018-01-18',
#  '2018-01-19',
#  '2018-01-20',
#  '2018-01-21',
#  '2018-01-22',
#  '2018-01-23',
#  '2018-01-24',
#  '2018-01-25',
#  '2018-01-26',
#  '2018-01-27',
#  '2018-01-28',
#  '2018-01-29',
#  '2018-01-30',
#  '2018-01-31',
#  '2018-02-01',
#  '2018-02-02',
#  '2018-02-03',
#  '2018-02-04',
#  '2018-02-05',
#  '2018-02-06',
#  '2018-02-07',
#  '2018-02-08',
#  '2018-02-09',
#  '2018-02-10',
#  '2018-02-11',
#  '2018-02-12',
#  '2018-02-13',
#  '2018-02-14',
#  '2018-02-15',
#  '2018-02-16',
#  '2018-02-17',
#  '2018-02-18',
#  '2018-02-19',
#  '2018-02-20',
#  '2018-02-21',
#  '2018-02-22',
#  '2018-02-23',
#  '2018-02-24',
#  '2018-02-25',
#  '2018-02-26',
#  '2018-02-27',
# ...

# %%
for date in date_generated5:
    days_range5.append(date.strftime("%Y-%m-%d"))
    
days_range5
# Out:
# ['2019-01-01',
#  '2019-01-02',
#  '2019-01-03',
#  '2019-01-04',
#  '2019-01-05',
#  '2019-01-06',
#  '2019-01-07',
#  '2019-01-08',
#  '2019-01-09',
#  '2019-01-10',
#  '2019-01-11',
#  '2019-01-12',
#  '2019-01-13',
#  '2019-01-14',
#  '2019-01-15',
#  '2019-01-16',
#  '2019-01-17',
#  '2019-01-18',
#  '2019-01-19',
#  '2019-01-20',
#  '2019-01-21',
#  '2019-01-22',
#  '2019-01-23',
#  '2019-01-24',
#  '2019-01-25',
#  '2019-01-26',
#  '2019-01-27',
#  '2019-01-28',
#  '2019-01-29',
#  '2019-01-30',
#  '2019-01-31',
#  '2019-02-01',
#  '2019-02-02',
#  '2019-02-03',
#  '2019-02-04',
#  '2019-02-05',
#  '2019-02-06',
#  '2019-02-07',
#  '2019-02-08',
#  '2019-02-09',
#  '2019-02-10',
#  '2019-02-11',
#  '2019-02-12',
#  '2019-02-13',
#  '2019-02-14',
#  '2019-02-15',
#  '2019-02-16',
#  '2019-02-17',
#  '2019-02-18',
#  '2019-02-19',
#  '2019-02-20',
#  '2019-02-21',
#  '2019-02-22',
#  '2019-02-23',
#  '2019-02-24',
#  '2019-02-25',
#  '2019-02-26',
#  '2019-02-27',
# ...

# %%
import time

# %%
# 수집 기간 맞추기
start_date = days_range[0]
end_date = (datetime.datetime.strptime(days_range[-1], "%Y-%m-%d") 
            + datetime.timedelta(days=1)).strftime("%Y-%m-%d") # setUntil이 끝을 포함하지 않으므로, day + 1

# %%
# 수집 기간 맞추기
start_date1 = days_range1[0]
end_date1 = (datetime.datetime.strptime(days_range1[-1], "%Y-%m-%d") 
            + datetime.timedelta(days=1)).strftime("%Y-%m-%d") # setUntil이 끝을 포함하지 않으므로, day + 1

# %%
# 수집 기간 맞추기
start_date2 = days_range2[0]
end_date2 = (datetime.datetime.strptime(days_range2[-1], "%Y-%m-%d") 
            + datetime.timedelta(days=1)).strftime("%Y-%m-%d") # setUntil이 끝을 포함하지 않으므로, day + 1

# %%
# 수집 기간 맞추기
start_date3 = days_range3[0]
end_date3 = (datetime.datetime.strptime(days_range3[-1], "%Y-%m-%d") 
            + datetime.timedelta(days=1)).strftime("%Y-%m-%d") # setUntil이 끝을 포함하지 않으므로, day + 1

# %%
# 수집 기간 맞추기
start_date4 = days_range4[0]
end_date4 = (datetime.datetime.strptime(days_range4[-1], "%Y-%m-%d") 
            + datetime.timedelta(days=1)).strftime("%Y-%m-%d") # setUntil이 끝을 포함하지 않으므로, day + 1

# %%
# 수집 기간 맞추기
start_date5 = days_range5[0]
end_date5 = (datetime.datetime.strptime(days_range5[-1], "%Y-%m-%d") 
            + datetime.timedelta(days=1)).strftime("%Y-%m-%d") # setUntil이 끝을 포함하지 않으므로, day + 1

# %% [markdown]
# ### 트윗 수집하기

# %%
# 트윗 수집 기준 정의
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('일본 불매운동')\
                                           .setSince(start_date)\
                                           .setUntil(end_date)\
                                           .setMaxTweets(-1)

# %%
# 트윗 수집 기준 정의
tweetCriteria1 = got.manager.TweetCriteria().setQuerySearch('일본 불매운동')\
                                           .setSince(start_date1)\
                                           .setUntil(end_date1)\
                                           .setMaxTweets(-1)

# %%
# 트윗 수집 기준 정의
tweetCriteria2 = got.manager.TweetCriteria().setQuerySearch('일본 불매운동')\
                                           .setSince(start_date2)\
                                           .setUntil(end_date2)\
                                           .setMaxTweets(-1)

# %%
# 트윗 수집 기준 정의
tweetCriteria3 = got.manager.TweetCriteria().setQuerySearch('일본 불매운동')\
                                           .setSince(start_date3)\
                                           .setUntil(end_date3)\
                                           .setMaxTweets(-1)

# %%
# 트윗 수집 기준 정의
tweetCriteria4 = got.manager.TweetCriteria().setQuerySearch('일본 불매운동')\
                                           .setSince(start_date4)\
                                           .setUntil(end_date4)\
                                           .setMaxTweets(-1)

# %%
# 트윗 수집 기준 정의
tweetCriteria5 = got.manager.TweetCriteria().setQuerySearch('일본 불매운동')\
                                           .setSince(start_date5)\
                                           .setUntil(end_date5)\
                                           .setMaxTweets(-1)

# %%
# 수집 with GetOldTweet3
print("Collecting data start.. from {} to {}".format(days_range[0], days_range[-1]))

start_time = time.time()

tweet = got.manager.TweetManager.getTweets(tweetCriteria)

print("Collecting data end.. {0:0.2f} Minutes".format((time.time() - start_time)/60))
print("=== Total num of tweets is {} ===".format(len(tweet)))
# Out:
# ...
# === Total num of tweets is 29705 ===

# %%
# 수집 with GetOldTweet3
print("Collecting data start.. from {} to {}".format(days_range1[0], days_range5[-1]))

start_time = time.time()

tweet1 = got.manager.TweetManager.getTweets(tweetCriteria1)

print("Collecting data end.. {0:0.2f} Minutes".format((time.time() - start_time)/60))
print("=== Total num of tweets is {} ===".format(len(tweet1)))
# Out:
# ...
# === Total num of tweets is 509 ===

# %%
tweet2 = got.manager.TweetManager.getTweets(tweetCriteria2)

print("Collecting data end.. {0:0.2f} Minutes".format((time.time() - start_time)/60))
print("=== Total num of tweets is {} ===".format(len(tweet2)))
# Out:
# ...
# === Total num of tweets is 167 ===

# %%
tweet3 = got.manager.TweetManager.getTweets(tweetCriteria3)
print("Collecting data end.. {0:0.2f} Minutes".format((time.time() - start_time)/60))
print("=== Total num of tweets is {} ===".format(len(tweet3)))
# Out:
# ...
# === Total num of tweets is 37 ===

# %%
tweet4 = got.manager.TweetManager.getTweets(tweetCriteria4)
print("Collecting data end.. {0:0.2f} Minutes".format((time.time() - start_time)/60))
print("=== Total num of tweets is {} ===".format(len(tweet4)))
# Out:
# ...
# === Total num of tweets is 301 ===

# %%
tweet5 = got.manager.TweetManager.getTweets(tweetCriteria5)
print("Collecting data end.. {0:0.2f} Minutes".format((time.time() - start_time)/60))
print("=== Total num of tweets is {} ===".format(len(tweet5)))
# Out:
# ...
# === Total num of tweets is 125 ===

# %% [markdown]
# ### 원하는 변수 골라서 저장하기
#
# #### (주의: 실행 시 약 24시간이 소요됩니다. 결과를 빨리 확인하려면 유저 정보 수집 부분을 전부 주석처리 해주세요.)

# %%
from random import uniform
from tqdm import tqdm_notebook

# %% [raw]
# # initialize
# tweet_list = []
#
# for index in tqdm_notebook(tweet):
#
#     # 메타데이터 목록
#     username = index.username
#     link = index.permalink
#     content = index.text
#     tweet_date = index.date.strftime("%Y-%m-%d")
#     tweet_time = index.date.strftime("%H:%M:%S")
#     retweets = index.retweets
#     favorites = index.favorites
#
#     # === 유저 정보 수집 시작 ===
#     try:
#         personal_link = 'https://twitter.com/' + username
#         bs_obj = get_bs_obj(personal_link)
#         uls = bs_obj.find("ul", {"class": "ProfileNav-list"}).find_all("li")
#         div = bs_obj.find("div", {"class": "ProfileHeaderCard-joinDate"}).find_all("span")[1]["title"]
#
#
#         # 가입일, 전체 트윗 수, 팔로잉 수, 팔로워 수
#         joined_date = div.split('-')[1].strip()
#         num_tweets = uls[0].find("span", {"class": "ProfileNav-value"}).text.strip()
#         num_following = uls[1].find("span", {"class": "ProfileNav-value"}).text.strip()
#         num_follower = uls[2].find("span", {"class": "ProfileNav-value"}).text.strip()
#
#     except AttributeError:
#         print("=== Attribute error occurs at {} ===".format(link))
#         print("link : {}".format(personal_link))
#         pass
#
#     # 결과 합치기
#     info_list = [tweet_date, tweet_time, username, content, link, retweets, favorites,
#                  joined_date, num_tweets, num_following, num_follower]
#     tweet_list.append(info_list)
#
#     # 휴식
#     time.sleep(uniform(1,2))

# %%
# initialize
tweet_list = []

for index in tqdm_notebook(tweet):
    #content = index.text
    tweet_date = index.date.strftime("%Y-%m-%d")
    
    tweet_list.append(tweet_date)
    
    time.sleep(1)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-441d3fa79a34> in <module>
#       8     tweet_list.append(tweet_date)
#       9
# ---> 10     time.sleep(1)
#
# KeyboardInterrupt:

# %%
# initialize
tweet_list1 = []

for index in tqdm_notebook(tweet1):
    content = index.text
    tweet_date = index.date.strftime("%Y-%m-%d")
    info_list=[content,tweet_date]
    tweet_list1.append(info_list)
    
    time.sleep(1)
    
    
    
    # initialize
tweet_list5 = []

for index in tqdm_notebook(tweet5):
    content = index.text
    tweet_date = index.date.strftime("%Y-%m-%d")
    info_list=[content,tweet_date]
    tweet_list5.append(info_list)
    
    time.sleep(1)
    
    
    
    
# initialize
tweet_list2 = []

for index in tqdm_notebook(tweet2):
    content = index.text
    tweet_date = index.date.strftime("%Y-%m-%d")
    info_list=[content,tweet_date]
    tweet_list2.append(info_list)
    time.sleep(1)
    
    
# initialize
tweet_list3 = []

for index in tqdm_notebook(tweet3):
    content = index.text
    tweet_date = index.date.strftime("%Y-%m-%d")
    info_list=[content,tweet_date]
    tweet_list3.append(info_list)
    time.sleep(1)
    

# initialize
tweet_list4 = []

for index in tqdm_notebook(tweet4):
    content = index.text
    tweet_date = index.date.strftime("%Y-%m-%d")
    info_list=[content,tweet_date]
    tweet_list4.append(info_list)
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-13e21179762f> in <module>
#       2 tweet_list1 = []
#       3
# ----> 4 for index in tqdm_notebook(tweet1):
#       5     content = index.text
#       6     tweet_date = index.date.strftime("%Y-%m-%d")
#
# NameError: name 'tweet1' is not defined

# %% [markdown]
# ### 파일 저장 후 확인

# %%
import pandas as pd

# %%
twitter_df_15=pd.DataFrame(tweet_list1,columns=["트위터","날짜"])
twitter_df_16=pd.DataFrame(tweet_list2,columns=["트위터","날짜"])
twitter_df_17=pd.DataFrame(tweet_list3,columns=["트위터","날짜"])
twitter_df_18=pd.DataFrame(tweet_list4,columns=["트위터","날짜"])
twitter_df_19=pd.DataFrame(tweet_list5,columns=["트위터","날짜"])

# %%
#파일 만들기
twitter_df_15.to_excel("twitter_data_{}_to_{}.xlsx".format(days_range1[0], days_range1[-1]), index=False)
print("=== {}tweets are successfully saved ===".format(len(tweet_list1)))
# Out:
# === 509tweets are successfully saved ===

# %%
#파일 만들기
twitter_df_16.to_excel("twitter_data_{}_to_{}.xlsx".format(days_range2[0], days_range2[-1]), index=False)
print("=== {}tweets are successfully saved ===".format(len(tweet_list2)))
# Out:
# === 167tweets are successfully saved ===

# %%
#파일 만들기
twitter_df_17.to_excel("twitter_data_{}_to_{}.xlsx".format(days_range3[0], days_range3[-1]), index=False)
print("=== {}tweets are successfully saved ===".format(len(tweet_list3)))
# Out:
# === 37tweets are successfully saved ===

# %%
#파일 만들기
twitter_df_18.to_excel("twitter_data_{}_to_{}.xlsx".format(days_range4[0], days_range4[-1]), index=False)
print("=== {}tweets are successfully saved ===".format(len(tweet_list4)))
# Out:
# === 301tweets are successfully saved ===

# %%
#파일 만들기
twitter_df_19.to_excel("twitter_data_{}_to_{}.xlsx".format(days_range5[0], days_range5[-1]), index=False)
print("=== {}tweets are successfully saved ===".format(len(tweet_list5)))
# Out:
# === 125tweets are successfully saved ===
